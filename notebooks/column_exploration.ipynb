# %% [markdown]
# # Column exploration
#
# The file `../data/unique_columns.txt` has a list of all the unique columns.

# %%
import pandas as pd

unique_columns = pd.read_csv('../data/unique_columns.txt', sep='\t', header=None)

print(f'There are {unique_columns.shape[0]} unique columns')

# %% [markdown]
# Just looking at the data, it looks like most concentration-response columns have some form of "activity at" in them.

# %%
import re
def find_activity_columns(column_string: str) -> bool:
    """ find columns that have the phrases "active" "at" and some number """
    # could change this to check for floats to be 
    # https://stackoverflow.com/questions/44506983/regex-to-check-if-a-string-is-a-number

    # some columns that can have digits but not concentration
    # still are not correct, such as 'IC50 #1 percent activity at max concentration'

    # this could be done by regular expression: https://stackoverflow.com/questions/38901699/find-numbers-in-a-string-not-preceded-or-followed-by-any-letters-in-javascript
    has_digit = any(char.isdigit() for char in column_string) and (('IC50' not in column_string) and ('AC50' not in column_string))
    has_activity = 'activity' in column_string.lower()
    # the at portion is difficult.  
    has_at = bool(re.search(r'\bat\b', column_string)) or '@' in column_string or bool(re.search('_at_', column_string))



    return has_digit and has_activity and has_at

# %%
unique_columns[0].apply(find_activity_columns).sum()

# %%
columns_not_matching = unique_columns[~unique_columns[0].apply(find_activity_columns)]
columns_matching = unique_columns[unique_columns[0].apply(find_activity_columns)]

# %%
print(f'{columns_matching[0].shape[0]}/{unique_columns[0].shape[0]} or {columns_matching[0].shape[0]/unique_columns[0].shape[0]*100:.2f}% fit the criteria')

# %% [markdown]
# Here is a list of columns that are not matching..

# %%
columns_not_matching[0].values.tolist()

# %%
columns_matching[0].values.tolist()

# %% [markdown]
# Looks like most are in uM, but lot all..

# %%
[col for col in columns_matching[0].values.tolist() if 'uM' not in col]

# %%
import warnings

def extract_units(column_string: str) -> float:
    """ given a columns_string pull outthe units
    so far looks like units can be nM, uM or mM 

    """
    units = re.findall('[unm]M', column_string)

    if not units:
        warnings.warn(f"Column: {column_string} could not find units!")
        units = [None]
    if len(units) > 1:
        warnings.warn(f"Column: {column_string} has more than one set of units!")
    return units[0] 

def extract_concentrations(column_string: str) -> float:
    """ given a columns_string pull out concentration 
    https://stackoverflow.com/questions/4289331/how-to-extract-numbers-from-a-string-in-python

    Regexr Website: https://regexr.com, https://regex101.com/

    """
    #digits = re.findall(r'\d+', column_string)
    # find digits surrounded by white space
    #digits = re.findall('\d+\.\d+.uM', column_string)

    # first get units 

    units = extract_units(column_string)
    
    digits = re.findall('\d.*?{}'.format(units), column_string)

    if not digits:
        warnings.warn(f"Column: {column_string} could not find concentration!")
        digits = [None]
    if len(digits) > 1:
        print(digits)
        warnings.warn(f"Column: {column_string} has more than one set of digits!")
    return digits[0]

# %%
columns_matching[0].apply(extract_concentrations)

# %%
columns_matching['Concentation'] = columns_matching[0].apply(extract_concentrations)

# %%
columns_matching[columns_matching['Concentation'].isnull()]

# %%
columns_matching[0].apply(extract_units).value_counts(dropna=False)

# %%
import pandas as pd

unique_columns = pd.read_csv('../data/unique_columns.txt', sep='\t', header=None)

print(f'There are {unique_columns.shape[0]} unique columns')
# Out:
# There are 47531 unique columns

# %% [markdown]
# Just looking at the data, it looks like most concentration-response columns have some form of "activity at" in them.

# %%
import re
def find_activity_columns(column_string: str) -> bool:
    """ find columns that have the phrases "active" "at" and some number """
    # could change this to check for floats to be 
    # https://stackoverflow.com/questions/44506983/regex-to-check-if-a-string-is-a-number

    # some columns that can have digits but not concentration
    # still are not correct, such as 'IC50 #1 percent activity at max concentration'

    # this could be done by regular expression: https://stackoverflow.com/questions/38901699/find-numbers-in-a-string-not-preceded-or-followed-by-any-letters-in-javascript
    has_digit = any(char.isdigit() for char in column_string) and (('IC50' not in column_string) and ('AC50' not in column_string))
    has_activity = 'activity' in column_string.lower()
    # the at portion is difficult.  
    has_at = bool(re.search(r'\bat\b', column_string)) or '@' in column_string or bool(re.search('_at_', column_string))



    return has_digit and has_activity and has_at

# %%
unique_columns[0].apply(find_activity_columns).sum()
# Out:
# 42570

# %%
columns_not_matching = unique_columns[~unique_columns[0].apply(find_activity_columns)]
columns_matching = unique_columns[unique_columns[0].apply(find_activity_columns)]

# %%
print(f'{columns_matching[0].shape[0]}/{unique_columns[0].shape[0]} or {columns_matching[0].shape[0]/unique_columns[0].shape[0]*100:.2f}% fit the criteria')
# Out:
# 42570/47531 or 89.56% fit the criteria

# %% [markdown]
# Here is a list of columns that are not matching..

# %%
columns_not_matching[0].values.tolist()
# Out:
# ['Ratio-Fit_ZeroActivity-Replicate_29',
#  'W535-Max_Response-Replicate_24',
#  '% Inhibition at 3.3 uM, #3',
#  'W535-Fit_R2-Replicate_42',
#  'IC50 #1 plate Z-factor',
#  'W620-Fit_HillSlope-Replicate_34',
#  'Conc1 Rep2',
#  'W535-Fit_HillSlope-Replicate_45',
#  'Surviving cells at 0.080 uM [1]',
#  'W460-Fit_R2-Replicate_33',
#  'Pct Inhibition @ 0.781 uM Rep3',
#  'Max Inhibition Conc',
#  'W665-Max_Response-Replicate_51',
#  'W590-Max_Response-Replicate_41',
#  'W615-Fit_R2-Replicate_47',
#  'Hill_Slope_TEST5',
#  'W460-Fit_R2-Replicate_25',
#  'Inhibition at 0.010 uM [2]',
#  'W460-Max_Response-Replicate_14',
#  'Max CPE Inhibition Conc',
#  'W460-Fit_LogAC50-Replicate_43',
#  'Potency-Replicate_17',
#  'Inhibition at 0.400 uM [2]',
#  'Fit_CurveClass-Replicate_4',
#  'Ratio-Fit_CurveClass-Replicate_54',
#  'Sinf_(%)_TEST3',
#  'Ratio-Fit_R2-Replicate_24',
#  'W620-Fit_HillSlope-Replicate_45',
#  'Fed-Fit_R2',
#  'W620-Fit_CurveClass-Replicate_20',
#  'W460-Max_Response-Replicate_12',
#  'Ratio-Fit_R2-Replicate_12',
#  'W615-Fit_ZeroActivity-Replicate_4',
#  'Concentration of Maximum Inhibition with NO Meropenem',
#  'W460-Fit_LogAC50-Replicate_19',
#  'Max Pct Vero Cell Viability',
#  '% Inhibition @ 5 uM',
#  'W535-Fit_InfiniteActivity-Replicate_33',
#  'Ratio-Fit_CurveClass-Replicate_39',
#  'W530-Fit_InfiniteActivity-Replicate_47',
#  'Primary Inhibition ',
#  'Inhibition at 1 uM [3]',
#  'Red-Fit_InfiniteActivity',
#  'Fed-Fit_ZeroActivity',
#  'W590-Fit_CurveClass-Replicate_31',
#  'W615-Fit_LogAC50-Replicate_15',
#  'W665-Fit_ZeroActivity-Replicate_44',
#  'Ratio-Fit_CurveClass-Replicate_11',
#  'W460-Fit_ZeroActivity-Replicate_50',
#  'W665-Fit_LogAC50-Replicate_49',
#  'W665-Fit_InfiniteActivity-Replicate_36',
#  'W620-Fit_ZeroActivity-Replicate_11',
#  'Pct Inhibition @ 6.25 uM Rep1',
#  'W535-Fit_HillSlope-Replicate_35',
#  'Ratio-Fit_HillSlope-Replicate_31',
#  '0.1 uM POC  0 uM Cpd',
#  'EC50 Max',
#  '% CPE Inhibition @ 0.781 uM',
#  'W615-Max_Response-Replicate_37',
#  'W665-Fit_LogAC50-Replicate_34',
#  'W530-Fit_InfiniteActivity-Replicate_1',
#  'W615-Fit_ZeroActivity',
#  'W590-Fit_ZeroActivity-Replicate_10',
#  'W615-Fit_R2-Replicate_18',
#  'Fit_LogAC50-Replicate_15',
#  'W665-Fit_LogAC50-Replicate_46',
#  'Ratio-Fit_ZeroActivity-Replicate_17',
#  'W665-Max_Response-Replicate_11',
#  'Ratio-Fit_LogAC50-Replicate_12',
#  '% Inhibition of H37Rv @ 100 uM',
#  'W665-Fit_ZeroActivity-Replicate_33',
#  'activity-Fit_InfiniteActivity',
#  'W460-Max_Response-Replicate_40',
#  'W620-Max_Response-Replicate_20',
#  'Fit_R2-Replicate_40',
#  'Ratio-Fit_ZeroActivity-Replicate_24',
#  'RSQR ',
#  'Surviving cells at 0.0032 uM [2]',
#  'W665-Fit_R2-Replicate_26',
#  'W665-Fit_R2-Replicate_6',
#  'W535-Fit_LogAC50-Replicate_28',
#  'W665-Max_Response-Replicate_1',
#  'DR Curve Bottom',
#  '%Inhibition_0.46uM',
#  'Viability @ 30 uM',
#  'W615-Fit_CurveClass-Replicate_47',
#  'Fluor-Fit_LogAC50',
#  'Ratio-Max_Response-Replicate_55',
#  'Total-Fluor-Inty-Fit_HillSlope',
#  'H37Rv PctInh @ 0.39 uM',
#  'W615-Fit_R2-Replicate_24',
#  'W665-Fit_LogAC50-Replicate_45',
#  'W620-Max_Response-Replicate_26',
#  'Inhibition @ 10 uM',
#  'Fit_LogAC50-Replicate_51',
#  'W535-Max_Response-Replicate_19',
#  'Inhibition at 2.5 uM [2]',
#  'LogEC50',
#  'Mutant IC50',
#  'W530-Fit_ZeroActivity-Replicate_24',
#  'Potency-Replicate_44',
#  'W460-Fit_CurveClass-Replicate_42',
#  'YFP-preread-Fit_LogAC50',
#  'Conc2 Rep5',
#  'Ratio-Fit_InfiniteActivity',
#  '% Inhibition at 10 uM, #3',
#  'W620-Fit_CurveClass-Replicate_40',
#  'W460-Fit_LogAC50-Replicate_50',
#  'Fit_ZeroActivity-Replicate_29',
#  'Max_Response-Replicate_33',
#  'W665-Max_Response-Replicate_2',
#  'W530-Fit_ZeroActivity-Replicate_9',
#  'W590-Fit_R2-Replicate_25',
#  'W615-Fit_LogAC50-Replicate_22',
#  'Ratio-Max_Response-Replicate_25',
#  'Ratio-Fit_CurveClass-Replicate_23',
#  'W535-Fit_HillSlope-Replicate_36',
#  'Ratio-Fit_CurveClass-Replicate_48',
#  'Fit_ZeroActivity-Replicate_49',
#  'W615-Fit_CurveClass-Replicate_39',
#  'Ratio-Fit_R2-Replicate_15',
#  'Fold Increase @ 3.75 uM',
#  'WT Inhibition @ 0.098 uM',
#  'W590-Max_Response-Replicate_7',
#  '% Inhibition of H37Rv @ 25 uM',
#  'W530-Fit_CurveClass-Replicate_36',
#  '% Inhibition @ 0.55 uM',
#  'Fit_InfiniteActivity-Replicate_17',
#  'W665-Fit_LogAC50-Replicate_23',
#  'W615-Fit_R2-Replicate_45',
#  'Ratio-Fit_CurveClass-Replicate_9',
#  'W615-Max_Response-Replicate_19',
#  'W530-Fit_InfiniteActivity-Replicate_45',
#  'W535-Fit_HillSlope-Replicate_9',
#  '% Cell Viability @ 0.781uM',
#  'W530-Fit_CurveClass-Replicate_33',
#  'W665-Fit_CurveClass-Replicate_49',
#  'Fold Increase @ 0.049 uM',
#  'W535-Fit_CurveClass-Replicate_45',
#  '% CPE Inhibition @ 0.078 uM (Replicate 2)',
#  'W665-Fit_LogAC50-Replicate_19',
#  'W530-Fit_R2',
#  'W460-Fit_HillSlope-Replicate_53',
#  'Fold Increase @1.25 ug/ml Rep1',
#  'Fit_InfiniteActivity-Replicate_42',
#  'W615-Fit_CurveClass-Replicate_28',
#  'W620-Fit_CurveClass-Replicate_14',
#  'Std.Err(EC50)_3',
#  'AID-Fit_R2',
#  'W590-Fit_LogAC50-Replicate_34',
#  'W665-Fit_HillSlope-Replicate_46',
#  'W590-Fit_ZeroActivity-Replicate_11',
#  'Inhibition at 0.030 uM [3]',
#  'Fit_ZeroActivity-Replicate_2',
#  'Ratio-Fit_ZeroActivity-Replicate_46',
#  'Fit_CurveClass-Replicate_8',
#  'W615-Fit_ZeroActivity-Replicate_38',
#  'W530-Fit_HillSlope-Replicate_18',
#  'W615-Fit_LogAC50-Replicate_14',
#  'W535-Fit_LogAC50-Replicate_4',
#  'Potency-Replicate_48',
#  'W590-Fit_InfiniteActivity-Replicate_1',
#  '% Inhibition @ 3.13 uM',
#  '%Inhibition_4.1uM_SD',
#  'W530-Fit_CurveClass-Replicate_45',
#  'W620-Fit_HillSlope-Replicate_35',
#  'fed-Fit_InfiniteActivity',
#  'W530-Fit_LogAC50-Replicate_44',
#  'W460-Fit_ZeroActivity-Replicate_38',
#  'W535-Fit_CurveClass-Replicate_21',
#  'Fit_ZeroActivity-Replicate_41',
#  'W665-Fit_ZeroActivity-Replicate_10',
#  'Ratio-Fit_CurveClass-Replicate_28',
#  'Inhibition at 0.0832 uM [3]',
#  'AID-Fit_HillSlope',
#  'Ratio-Fit_CurveClass-Replicate_26',
#  'FITC-Fit_HillSlope',
#  'W460-Fit_ZeroActivity-Replicate_2',
#  'W530-Max_Response-Replicate_25',
#  'W620-Max_Response-Replicate_49',
#  'W460-Max_Response-Replicate_52',
#  'Ratio-Fit_CurveClass-Replicate_49',
#  'W665-Fit_LogAC50-Replicate_41',
#  'Inhibition at 6.6 uM [3]',
#  'EC50 Hill Slope',
#  'W620-Fit_ZeroActivity-Replicate_48',
#  '%Inhibition_37uM_SD',
#  'W590-Max_Response-Replicate_10',
#  'W620-Fit_ZeroActivity-Replicate_17',
#  'Efficacy-Replicate_17',
#  'RFP-Fit_InfiniteActivity',
#  'WT Inhibition @ 0.781 uM',
#  'W620-Fit_ZeroActivity-Replicate_23',
#  'Pct_Viability @12.5 uM Rep1',
#  'W590-Fit_R2-Replicate_7',
#  'W590-Fit_HillSlope-Replicate_6',
#  'W615-Fit_ZeroActivity-Replicate_6',
#  'W460-Fit_R2-Replicate_23',
#  'W530-Fit_CurveClass-Replicate_51',
#  'Max_Activity_Conc_uM_TEST3',
#  'W535-Fit_InfiniteActivity-Replicate_11',
#  'EC50_4',
#  'W535-Fit_ZeroActivity-Replicate_2',
#  'W460-Fit_R2-Replicate_24',
#  'W460-Fit_ZeroActivity-Replicate_7',
#  'W530-Fit_CurveClass-Replicate_23',
#  'W615-Fit_CurveClass-Replicate_11',
#  'W615-Max_Response-Replicate_50',
#  'W460-Fit_R2-Replicate_12',
#  'Max WT Max Inhibition',
#  'W460-Fit_InfiniteActivity-Replicate_10',
#  'W620-Fit_R2-Replicate_18',
#  'W530-Fit_HillSlope-Replicate_17',
#  'W615-Max_Response-Replicate_10',
#  '0.003 uM POC  0 uM Cpd',
#  'Ratio-Fit_HillSlope-Replicate_1',
#  'W620-Fit_InfiniteActivity-Replicate_30',
#  'Potency-Replicate_7',
#  'W665-Fit_CurveClass-Replicate_10',
#  'Pct Vero Cell Viability @ 20 uM',
#  'W620-Fit_LogAC50-Replicate_26',
#  'W530-Max_Response-Replicate_26',
#  'W590-Fit_CurveClass-Replicate_15',
#  'W530-Fit_CurveClass-Replicate_39',
#  'Primary % CPE Inhibition @ 10 uM (Rep 3)',
#  'Fit_R2-Replicate_27',
#  'CFP-preread-Max_Response',
#  'Max_Response-Replicate_23',
#  'W535-Max_Response-Replicate_3',
#  'W615-Fit_LogAC50-Replicate_10',
#  'fed-Fit_CurveClass',
#  'W620-Max_Response-Replicate_29',
#  'W535-Max_Response-Replicate_2',
#  'Ratio-Fit_CurveClass-Replicate_5',
#  'W530-Fit_CurveClass-Replicate_37',
#  'W535-Fit_LogAC50-Replicate_38',
#  'W460-Fit_R2-Replicate_36',
#  '% Inhibition at 1.1 uM, #1',
#  'W460-Fit_R2-Replicate_16',
#  'Ratio-Fit_HillSlope-Replicate_26',
#  'W460-Fit_LogAC50-Replicate_7',
#  'Fit_ZeroActivity-Replicate_16',
#  'W620-Fit_HillSlope-Replicate_4',
#  'W460-Fit_HillSlope-Replicate_17',
#  '% CPE Inhibition @ 20 uM (Replicate 2)',
#  'Potency-Replicate_14',
#  'W620-Fit_CurveClass-Replicate_46',
#  'W665-Fit_InfiniteActivity-Replicate_3',
#  'W615-Fit_ZeroActivity-Replicate_43',
#  'W665-Fit_ZeroActivity-Replicate_5',
#  'W665-Max_Response-Replicate_41',
#  'Conc6 Rep2',
#  'Pct Vero Cell Viability @ 2.5 uM',
#  'W665-Fit_R2-Replicate_28',
#  'Max_Response-Replicate_2',
#  'W590-Fit_HillSlope-Replicate_19',
#  'W530-Fit_R2-Replicate_18',
#  'cells-Max_Response',
#  'Pct THP-1 Cell Viability @ 0.078 uM',
#  'W590-Fit_CurveClass-Replicate_8',
#  'W615-Fit_CurveClass-Replicate_22',
#  'Ratio-Fit_HillSlope-Replicate_30',
#  'PGE2 EC50 (0 uM)',
#  'W590-Fit_LogAC50-Replicate_20',
#  'fed-Fit_LogAC50',
#  'W535-Fit_CurveClass-Replicate_13',
#  'Mutant Inhibition @ 0.781 uM',
#  'Fold Increase @0.156 ug/ml Rep1',
#  '%Inhibition_0.46uM_SD',
#  'Min Pct Vero Cell Viability',
#  'Fit_CurveClass-Replicate_32',
#  'W460-Max_Response-Replicate_50',
#  'W530-Fit_HillSlope-Replicate_5',
#  'IC50 #1 signal at 0.78125 microM',
#  'CBG-Fit_HillSlope',
#  'W665-Max_Response-Replicate_45',
#  'Ratio-Fit_CurveClass-Replicate_53',
#  'W530-Fit_R2-Replicate_48',
#  'Fit_CurveClass-Replicate_38',
#  'Ratio-Fit_CurveClass-Replicate_16',
#  'W665-Fit_R2-Replicate_35',
#  '% Viability @ 20 uM',
#  'CC50 NormChi2 ',
#  'Ratio-Fit_HillSlope-Replicate_33',
#  'Conc5 Rep4',
#  'W460-Fit_LogAC50-Replicate_4',
#  'nH_1_Range1',
#  'Ratio-Fit_InfiniteActivity-Replicate_9',
#  'Efficacy-Replicate_28',
#  'Ratio-Max_Response-Replicate_53',
#  '% Viability @ 0.19 uM ',
#  'Pct_Viability @0.39 uM Rep2',
#  'W665-Fit_LogAC50-Replicate_18',
#  'Max_Response-Replicate_26',
#  'Max % Inhibition of H37Rv',
#  'Concentration of Maximum Inhibition with Meropenem',
#  'W460-Fit_InfiniteActivity-Replicate_49',
#  'W615-Fit_HillSlope-Replicate_29',
#  'Ratio-Fit_HillSlope-Replicate_44',
#  'W460-Fit_LogAC50',
#  'W615-Fit_ZeroActivity-Replicate_27',
#  'W535-Fit_ZeroActivity',
#  'Fold Increase @ 7.5uM',
#  'W665-Fit_CurveClass-Replicate_19',
#  'WT Inhibition @ 0.195 uM',
#  'H37Rv with Meropenem PctInh @ 6.25 uM',
#  'W535-Fit_ZeroActivity-Replicate_16',
#  'W590-Fit_R2-Replicate_14',
#  'Pct Vero Cell Viability @ 10 uM',
#  'W665-Fit_ZeroActivity-Replicate_49',
#  'W590-Fit_ZeroActivity-Replicate_8',
#  '% Inhibition @ 10 uM',
#  'W460-Fit_LogAC50-Replicate_47',
#  'W530-Fit_CurveClass-Replicate_55',
#  'Concentration of Min Pct Vero Cell Viability',
#  '%Inhibition_1.37uM_SD',
#  'W620-Fit_LogAC50-Replicate_6',
#  'W615-Fit_CurveClass-Replicate_23',
#  '% Inhibition @ 20 uM',
#  'delta-Fit_HillSlope',
#  'W590-Max_Response-Replicate_38',
#  'W460-Fit_HillSlope',
#  'W530-Fit_R2-Replicate_55',
#  'IC50 NormChi2',
#  'W535-Fit_R2',
#  '% Inhibition @ 1.56 uM',
#  'Fit_CurveClass-Replicate_18',
#  'W620-Fit_LogAC50-Replicate_15',
#  'Ratio-Fit_R2-Replicate_54',
#  'W615-Fit_InfiniteActivity-Replicate_1',
#  'Pct THP-1 Cell Viability @ 0.313 uM',
#  'Inhibition at 10 uM [2]',
#  'W530-Fit_HillSlope-Replicate_31',
#  'Log IC50',
#  'Surviving Cells at 50 uM [5]',
#  'Ratio-Fit_HillSlope-Replicate_24',
#  'Ratio-Max_Response-Replicate_44',
#  'Efficacy-Replicate_30',
#  'W460-Fit_R2-Replicate_3',
#  'Cytotox-Fit_CurveClass',
#  'W530-Max_Response-Replicate_30',
#  'Primary % Inhibition @ 20 uM (Rep 1)',
#  'W530-Max_Response-Replicate_1',
#  'Fit_InfiniteActivity-Replicate_47',
#  'Fit_CurveClass-Replicate_33',
#  'Ratio-Max_Response-Replicate_40',
#  'ratio at 6.67uM',
#  'AID-Fit_CurveClass',
#  'Inhibition at 0 uM [1]',
#  'W615-Fit_LogAC50-Replicate_20',
#  'Efficacy-Replicate_8',
#  'Fit_HillSlope-Replicate_50',
#  'W615-Fit_HillSlope-Replicate_19',
#  'Ratio-Fit_ZeroActivity-Replicate_12',
#  'W620-Max_Response-Replicate_5',
#  'W615-Fit_HillSlope-Replicate_46',
#  'Ratio-Fit_HillSlope-Replicate_14',
#  'Inhibition @ 25 uM',
#  'Ratio-Fit_CurveClass',
#  'W590-Fit_ZeroActivity-Replicate_22',
#  'H37Rv PctInh @ 100 uM',
#  'W460-Max_Response-Replicate_27',
#  'W665-Fit_LogAC50-Replicate_14',
#  'Ratio-Fit_LogAC50-Replicate_33',
#  'W535-Fit_R2-Replicate_44',
#  'W615-Fit_LogAC50-Replicate_47',
#  'pAbsAC40_M_TEST3',
#  'Primary Screen Percent Inhibition @ 25 uM Rep 1',
#  'W620-Fit_ZeroActivity-Replicate_21',
#  'Ratio-Fit_ZeroActivity-Replicate_35',
#  'Surviving cells at 0.016 uM [3]',
#  'Fold Increase @10 ug/ml Rep1',
#  'Ratio-Fit_LogAC50-Replicate_22',
#  'W665-Fit_ZeroActivity-Replicate_12',
#  'W665-Max_Response-Replicate_44',
#  'W590-Fit_HillSlope-Replicate_9',
#  'W460-Fit_R2-Replicate_38',
#  'W665-Fit_ZeroActivity-Replicate_30',
#  'Inhibition at 0.010 uM [3]',
#  'W665-Fit_InfiniteActivity-Replicate_51',
#  'W535-Max_Response-Replicate_6',
#  'Inhibition at 0.25 uM [2]',
#  'W590-Fit_R2-Replicate_9',
#  'W590-Fit_ZeroActivity-Replicate_35',
#  'Fit NormChi2',
#  'Pct Inhibition @ 1.56 uM Rep2',
#  'Fit_LogAC50-Replicate_25',
#  '% Viability @ 10 uM',
#  'W535-Max_Response-Replicate_37',
#  '% Inhibition @ 30 uM (Primary Screen Rep 3)',
#  'Fit_LogAC50-Replicate_42',
#  '% Inhibition of H37Rv in Primary Screen Rep3',
#  'Pct Vero Cell Viability @ 0.156 uM',
#  'W665-Max_Response-Replicate_20',
#  'IC50 Normalized Chi2',
#  'W620-Fit_InfiniteActivity-Replicate_35',
#  'Ratio-Fit_ZeroActivity-Replicate_3',
#  'Efficacy-Replicate_5',
#  'W535-Fit_R2-Replicate_16',
#  'Inhibition at 0.000033 uM [2]',
#  'W620-Fit_InfiniteActivity-Replicate_45',
#  '3.1uM POC',
#  'W460-Max_Response-Replicate_18',
#  'W590-Fit_CurveClass-Replicate_23',
#  'Percent Inhibition @ 1.17 uM',
#  'W620-Fit_R2-Replicate_4',
#  'Fit_HillSlope-Replicate_30',
#  'W590-Fit_ZeroActivity-Replicate_42',
#  'Bottom (20 uM)',
#  'W665-Fit_CurveClass-Replicate_32',
#  'W665-Fit_HillSlope-Replicate_33',
#  'CFP-preread-Fit_LogAC50',
#  'W460-Fit_LogAC50-Replicate_9',
#  'W665-Fit_ZeroActivity-Replicate_50',
#  'LogIC50',
#  'W530-Fit_LogAC50-Replicate_52',
#  'W615-Fit_ZeroActivity-Replicate_8',
#  'W460-Fit_HillSlope-Replicate_39',
#  'Ratio-Fit_InfiniteActivity-Replicate_24',
#  'W615-Fit_InfiniteActivity-Replicate_21',
#  '0.0003 uM POC  0 uM Cpd',
#  'W590-Fit_LogAC50-Replicate_45',
#  'W620-Fit_HillSlope-Replicate_36',
#  'W530-Fit_LogAC50-Replicate_18',
#  'Mutant Inhibition @ 0.195 uM',
#  'W530-Fit_ZeroActivity-Replicate_54',
#  'W590-Fit_InfiniteActivity-Replicate_15',
#  'Primary Inhibition @ 30 uM Rep 1',
#  'W615-Fit_CurveClass-Replicate_24',
#  'W535-Fit_CurveClass-Replicate_18',
#  'Ratio-Fit_HillSlope-Replicate_27',
#  '% Viability  @ 0.10 uM',
#  'W590-Max_Response-Replicate_39',
#  'W665-Fit_HillSlope-Replicate_44',
#  'W460-Fit_LogAC50-Replicate_24',
#  'W665-Fit_R2-Replicate_21',
#  'W535-Fit_InfiniteActivity-Replicate_29',
#  'W460-Max_Response-Replicate_41',
#  'Cell Viability at 0.01 uM [5]',
#  'W590-Fit_R2-Replicate_5',
#  'W590-Fit_CurveClass-Replicate_12',
#  'Surviving Cells at 2 uM [4]',
#  'Cell Viability at 100 uM [5]',
#  'W460-Fit_InfiniteActivity-Replicate_27',
#  'W530-Fit_InfiniteActivity-Replicate_20',
#  'Inhibition at 50 uM [3]',
#  'Pct Inhibition @ 0.39 uM Rep3',
#  'W590-Fit_CurveClass-Replicate_25',
#  'FF-overN-Fit_HillSlope',
#  'W460-Max_Response-Replicate_30',
#  'W620-Fit_CurveClass-Replicate_33',
#  'W615-Max_Response-Replicate_34',
#  'W615-Fit_R2-Replicate_25',
#  'Cell Viability at 2 uM [3]',
#  'Fit_ZeroActivity-Replicate_9',
#  'W665-Fit_HillSlope-Replicate_45',
#  '% CPE Inhibition @ 0.313 uM (Replicate 2)',
#  'W615-Fit_R2-Replicate_36',
#  'Percent Inhibition @ 9.38 uM',
#  'W460-Fit_CurveClass-Replicate_19',
#  'IC50 #1 control percent CV',
#  'Efficacy-Replicate_31',
#  'W535-Fit_ZeroActivity-Replicate_42',
#  'Fold Increase @ 0.195 uM',
#  'ratio-postread-Fit_LogAC50',
#  'W620-Fit_InfiniteActivity-Replicate_32',
#  'Ratio-Fit_R2-Replicate_29',
#  'Fit_HillSlope-Replicate_39',
#  'PrimaryPilotScreen PctInh (R1)',
#  'W530-Fit_R2-Replicate_32',
#  'W590-Fit_ZeroActivity-Replicate_7',
#  'W615-Fit_InfiniteActivity-Replicate_4',
#  'Fit_CurveClass-Replicate_45',
#  'Pct Inhibition @ 3.13 uM Rep3',
#  'Max_Response-Replicate_36',
#  'W590-Fit_LogAC50-Replicate_22',
#  'W665-Max_Response-Replicate_26',
#  'Ratio-Fit_ZeroActivity-Replicate_27',
#  'W460-Fit_CurveClass-Replicate_30',
#  'W620-Fit_ZeroActivity-Replicate_26',
#  'Green-Max_Response',
#  'nH_3',
#  'W530-Max_Response-Replicate_29',
#  'Viability at 10 uM [3]',
#  'W615-Fit_R2-Replicate_38',
#  'Ratio-Fit_LogAC50-Replicate_36',
#  'W460-Fit_LogAC50-Replicate_39',
#  'W665-Max_Response-Replicate_3',
#  '% CPE Inhibition @ 0.156 uM(Replicate 1)',
#  'W615-Max_Response-Replicate_43',
#  'Ratio-Fit_ZeroActivity-Replicate_7',
#  'W535-Max_Response-Replicate_41',
#  'W535-Fit_CurveClass-Replicate_31',
#  'W665-Fit_ZeroActivity-Replicate_19',
#  'W535-Fit_CurveClass-Replicate_19',
#  'W530-Fit_R2-Replicate_40',
#  'Pilot 10K Screen % Inhibition @ 25 uM Rep 1',
#  'W535-Fit_HillSlope-Replicate_26',
#  'W620-Max_Response-Replicate_18',
#  'Ratio-Fit_CurveClass-Replicate_24',
#  'W590-Fit_LogAC50-Replicate_28',
#  'W535-Fit_HillSlope-Replicate_43',
#  'W590-Fit_R2-Replicate_40',
#  'W615-Fit_ZeroActivity-Replicate_7',
#  'Cell Viability at 1 uM [3]',
#  'W615-Fit_CurveClass-Replicate_49',
#  'W460-Fit_CurveClass-Replicate_27',
#  'Fit_HillSlope-Replicate_10',
#  'W530-Fit_CurveClass',
#  'Max_Response-Replicate_50',
#  'Fit_ZeroActivity-Replicate_24',
#  'W615-Fit_HillSlope-Replicate_12',
#  'W620-Fit_HillSlope-Replicate_16',
#  'W620-Max_Response-Replicate_50',
#  'W615-Fit_R2-Replicate_28',
#  '% Inhibition @ 0.23 uM',
#  'Pct_Viability @2.5 ug/ml Rep1',
#  'W665-Fit_HillSlope-Replicate_43',
#  'W530-Fit_CurveClass-Replicate_53',
#  'W615-Fit_HillSlope-Replicate_43',
#  'W615-Fit_InfiniteActivity-Replicate_47',
#  'W665-Fit_CurveClass-Replicate_34',
#  'W530-Fit_HillSlope-Replicate_54',
#  'Potency-Replicate_30',
#  'W535-Fit_CurveClass-Replicate_44',
#  'W665-Fit_ZeroActivity-Replicate_4',
#  'W665-Fit_HillSlope-Replicate_14',
#  'Activity At IC50 (6.7 uM)',
#  'W460-Fit_R2',
#  'SD at 246.91nM',
#  'Fit_InfiniteActivity-Replicate_34',
#  '% Inhibition @ 100 uM',
#  'W460-Fit_HillSlope-Replicate_49',
#  'Fit Hill Slope Rep2',
#  'W530-Fit_CurveClass-Replicate_15',
#  'brca1-p1_activity-Fit_HillSlope',
#  'W590-Max_Response-Replicate_4',
#  'W535-Fit_LogAC50-Replicate_41',
#  '% Cell Viability @ 0.039 uM',
#  'W590-Max_Response-Replicate_35',
#  'Ratio-Fit_HillSlope-Replicate_19',
#  'CFP-preread-Fit_CurveClass',
#  'W535-Fit_R2-Replicate_36',
#  'W535-Fit_HillSlope-Replicate_13',
#  'W530-Fit_CurveClass-Replicate_2',
#  'Ratio-Fit_HillSlope-Replicate_32',
#  'Fit_HillSlope-Replicate_13',
#  'W535-Fit_R2-Replicate_18',
#  'Percent Inhibition @ 4.68 uM',
#  'W460-Fit_ZeroActivity-Replicate_51',
#  'Donor-Fit_R2',
#  'W460-Fit_LogAC50-Replicate_48',
#  'Total-Fluor-Inty-Fit_ZeroActivity',
#  'W615-Fit_CurveClass-Replicate_50',
#  'W620-Max_Response-Replicate_32',
#  'Viability at 0.01 uM [1]',
#  'W665-Fit_CurveClass-Replicate_15',
#  'W620-Fit_LogAC50-Replicate_40',
#  'W530-Fit_CurveClass-Replicate_35',
#  'W590-Fit_LogAC50-Replicate_12',
#  'W460-Fit_CurveClass-Replicate_52',
#  'W530-Fit_HillSlope-Replicate_13',
#  'W665-Fit_HillSlope-Replicate_20',
#  'W620-Fit_InfiniteActivity-Replicate_17',
#  'Pct_Viability @0.039 ug/ml Rep1',
#  'Inhibition at 1.25 uM [4]',
#  'W530-Fit_LogAC50-Replicate_11',
#  'Maximum Inhibition of H37Rv with Meropenem',
#  'Potency-Replicate_54',
#  'Activation @ 0.01 uM',
#  'Ratio-Fit_InfiniteActivity-Replicate_41',
#  'W530-Max_Response-Replicate_8',
#  'Fit_InfiniteActivity-Replicate_31',
#  '% CPE Inhibition @ 0.156 uM (Replicate 2)',
#  'W460-Max_Response-Replicate_45',
#  'W590-Fit_CurveClass-Replicate_43',
#  'H37Rv with Meropenem PctInh @ 12.5 uM',
#  'W460-Fit_HillSlope-Replicate_22',
#  'W460-Max_Response-Replicate_28',
#  'Max_Response-Replicate_51',
#  'EC50 Fit NormChi2',
#  'Inhibition at 0.000033 uM [3]',
#  'W535-Fit_ZeroActivity-Replicate_40',
#  'W615-Fit_CurveClass-Replicate_3',
#  'W665-Fit_InfiniteActivity-Replicate_49',
#  '% Viability @ 2.5 uM',
#  'W620-Fit_CurveClass-Replicate_34',
#  'Ratio-Fit_CurveClass-Replicate_27',
#  'W665-Fit_HillSlope-Replicate_35',
#  'W530-Fit_R2-Replicate_39',
#  'W620-Fit_HillSlope-Replicate_37',
#  'Ratio-Fit_ZeroActivity-Replicate_45',
#  'W590-Fit_LogAC50-Replicate_14',
#  'W535-Fit_LogAC50-Replicate_18',
#  'Efficacy-Replicate_11',
#  'IC50 #1 blank mean',
#  'IC50 #1 signal at 0.01221 microM',
#  'W590-Fit_CurveClass-Replicate_42',
#  'Ratio-Fit_CurveClass-Replicate_13',
#  'Fit Hill Slope Rep1',
#  'Primary Screen Percent Inhibition @ 12.5 uM Rep 1',
#  'Fit_ZeroActivity-Replicate_27',
#  '% CPE Inhibition @ 0.078 uM (Replicate 3)',
#  'Donor 2 EC50',
#  'Surviving Cells at 10 uM [5]',
#  'Ratio-Fit_CurveClass-Replicate_42',
#  'Fit_InfiniteActivity-Replicate_49',
#  'W590-Fit_InfiniteActivity-Replicate_3',
#  'Inhibition at 4 uM [1]',
#  'W665-Fit_CurveClass-Replicate_5',
#  'W620-Fit_LogAC50-Replicate_3',
#  'Fit_ZeroActivity-Replicate_26',
#  'Fit_ZeroActivity-Replicate_42',
#  'W615-Fit_R2-Replicate_34',
#  'Surviving Cells at 0.016 uM [4]',
#  'Fit_InfiniteActivity-Replicate_23',
#  'W530-Fit_LogAC50-Replicate_8',
#  'Fit_CurveClass-Replicate_23',
#  'W665-Fit_CurveClass-Replicate_24',
#  'Surviving Cells at 2 uM [5]',
#  'Inhibition at 0.246 uM [2]',
#  'Total_fluor_inty-Fit_LogAC50',
#  'W665-Max_Response-Replicate_40',
#  'W620-Fit_InfiniteActivity-Replicate_22',
#  'Fit_HillSlope-Replicate_11',
#  'Ratio-Max_Response-Replicate_35',
#  'W615-Fit_LogAC50-Replicate_18',
#  'Potency-Replicate_24',
#  'W620-Fit_CurveClass-Replicate_43',
#  'Ratio-Fit_LogAC50-Replicate_46',
#  '% CPE Inhibition @ 10 uM (Replicate 1)',
#  'W620-Fit_LogAC50-Replicate_11',
#  'brca1-p1_activity-Fit_LogAC50',
#  'W590-Fit_InfiniteActivity-Replicate_11',
#  'W615-Fit_R2',
#  'W620-Fit_CurveClass-Replicate_28',
#  '% Inhibition of H37Rv @ 0.781uM',
#  'Max_Concentration_uM_TEST3',
#  'W665-Fit_InfiniteActivity-Replicate_50',
#  'Bottom',
#  'W590-Fit_ZeroActivity-Replicate_2',
#  'Max_Activity_(%)_TEST2',
#  'W530-Max_Response-Replicate_17',
#  'W590-Fit_R2-Replicate_11',
#  'W535-Fit_HillSlope-Replicate_29',
#  'Fit_HillSlope-Replicate_37',
#  'W535-Fit_InfiniteActivity-Replicate_7',
#  'Surviving cells at 0.400 uM [1]',
#  'Max % Viability',
#  'AbsAC30_uM_TEST2',
#  '% Cell Viability @ 50 uM',
#  'W665-Fit_R2-Replicate_32',
#  'Fit_CurveClass-Replicate_20',
#  'Red-Fit_HillSlope',
#  'W535-Fit_InfiniteActivity-Replicate_34',
#  'W530-Fit_ZeroActivity-Replicate_18',
#  'W530-Fit_InfiniteActivity-Replicate_17',
#  'W535-Fit_R2-Replicate_39',
#  'W530-Fit_InfiniteActivity-Replicate_3',
#  'Mutant Inhibition @ 0.049 uM',
#  'W535-Max_Response-Replicate_44',
#  'ratio at 9.14nM',
#  'W590-Fit_R2-Replicate_2',
#  'W620-Fit_LogAC50-Replicate_49',
#  'RAWMCF_33.33_MICROM (33.33uM)',
#  'Hill_Slope_TEST4',
#  'Inhibition at 2 uM [1]',
#  'W460-Fit_InfiniteActivity-Replicate_44',
#  'Relative IC50 Error',
#  'EC50 Min',
#  'Ratio-Fit_CurveClass-Replicate_6',
#  'AbsAC30_uM',
#  'W535-Fit_InfiniteActivity-Replicate_32',
#  'W615-Fit_CurveClass-Replicate_26',
#  'fed-Fit_ZeroActivity',
#  'W615-Fit_HillSlope-Replicate_15',
#  'W665-Fit_InfiniteActivity-Replicate_21',
#  'IC50 Fit NormChi2',
#  'W615-Fit_InfiniteActivity-Replicate_5',
#  'W590-Fit_HillSlope-Replicate_17',
#  'W590-Fit_HillSlope-Replicate_33',
#  'Ratio-Fit_R2-Replicate_55',
#  'W590-Max_Response-Replicate_31',
#  'Fit_R2-Replicate_21',
#  'W460-Fit_R2-Replicate_49',
#  'W665-Fit_LogAC50-Replicate_22',
#  'W535-Fit_R2-Replicate_10',
#  'W535-Max_Response-Replicate_12',
#  'Cell Viability at 10 uM [3]',
#  'W535-Max_Response-Replicate_33',
#  'Primary CPE Inhibition Rep 4',
#  'W620-Fit_ZeroActivity-Replicate_15',
#  'W590-Fit_HillSlope-Replicate_21',
#  'Fold Increase @ 0.391 uM',
#  'W460-Max_Response-Replicate_33',
#  'W460-Fit_ZeroActivity-Replicate_33',
#  'W620-Fit_InfiniteActivity-Replicate_37',
#  'Ratio-Fit_InfiniteActivity-Replicate_33',
#  'W590-Fit_ZeroActivity-Replicate_5',
#  'W460-Fit_InfiniteActivity-Replicate_26',
#  'W535-Fit_ZeroActivity-Replicate_33',
#  'W460-Fit_HillSlope-Replicate_50',
#  'Cell-Fit_CurveClass',
#  'W460-Max_Response-Replicate_10',
#  'W615-Fit_CurveClass-Replicate_44',
#  'Fold Increase @ 10ug/ml',
#  'W530-Fit_ZeroActivity-Replicate_26',
#  'W590-Fit_HillSlope-Replicate_43',
#  'W620-Fit_R2-Replicate_17',
#  'W460-Fit_HillSlope-Replicate_24',
#  '0 uM POC  20 uM Cpd',
#  'W530-Fit_ZeroActivity-Replicate_15',
#  'W620-Fit_LogAC50-Replicate_31',
#  'Ratio-Fit_R2-Replicate_30',
#  'Pct Inhibition @ 3.13 uM Rep1',
#  'Pct_Viability @1.56 uM Rep2',
#  'W590-Fit_HillSlope-Replicate_36',
#  'WT Inhibition @ 0.049 uM',
#  'Fit_CurveClass-Replicate_39',
#  'Fit_InfiniteActivity-Replicate_27',
#  'Ratio-Fit_HillSlope-Replicate_6',
#  'W590-Fit_InfiniteActivity-Replicate_33',
#  'Ratio-Fit_R2-Replicate_27',
#  'W665-Fit_LogAC50-Replicate_40',
#  'Cell Viability at 0.01 uM [4]',
#  'W460-Fit_CurveClass-Replicate_22',
#  'Max_Response-Replicate_46',
#  'Ratio-Max_Response-Replicate_18',
#  'W615-Fit_CurveClass-Replicate_42',
#  'W460-Fit_R2-Replicate_44',
#  'ratio-postread-Fit_HillSlope',
#  'W460-Fit_R2-Replicate_27',
#  'W665-Fit_R2-Replicate_27',
#  'W620-Fit_LogAC50-Replicate_10',
#  'W460-Fit_CurveClass-Replicate_5',
#  'Inhibition at 0.400 uM [1]',
#  'W665-Fit_HillSlope-Replicate_23',
#  'Ratio-Fit_CurveClass-Replicate_34',
#  'Percent Inhibition @ 0.20 uM',
#  'Fit_ZeroActivity-Replicate_44',
#  'Total_Fluorescence-Fit_HillSlope',
#  'Inhibition at 0.37 uM {replicate 2}',
#  'W530-Fit_ZeroActivity-Replicate_38',
#  'W665-Fit_CurveClass-Replicate_17',
#  'W590-Fit_CurveClass-Replicate_35',
#  'W665-Fit_HillSlope-Replicate_34',
#  '% Viability  @ 0.20 uM',
#  'W530-Fit_ZeroActivity-Replicate_44',
#  'AbsAC30_uM_TEST1',
#  'Fit_HillSlope-Replicate_15',
#  'W665-Fit_ZeroActivity',
#  'Fit_LogAC50-Replicate_36',
#  'Inhibition at 0.00125 uM [3]',
#  'Surviving Cells at 0.08 uM [2]',
#  '% Viability @ 0.09 uM ',
#  'W665-Fit_R2',
#  'W620-Fit_CurveClass-Replicate_21',
#  'W535-Fit_ZeroActivity-Replicate_24',
#  '% Viability @ 0.3 uM',
#  'Red-Fit_ZeroActivity',
#  'W460-Fit_CurveClass-Replicate_35',
#  'W535-Fit_HillSlope-Replicate_14',
#  'Max_Response-Replicate_17',
#  'W615-Fit_InfiniteActivity-Replicate_11',
#  'W665-Fit_LogAC50-Replicate_37',
#  'W460-Fit_R2-Replicate_1',
#  'W620-Max_Response-Replicate_22',
#  'Fit_HillSlope-Replicate_14',
#  'W665-Max_Response-Replicate_49',
#  'Cell-Fit_R2',
#  'W590-Max_Response-Replicate_28',
#  'P Channel FOC at 12.5 uM',
#  'W530-Fit_InfiniteActivity-Replicate_31',
#  'Red-Fit_R2',
#  'Efficacy-Replicate_1',
#  'EC50_1',
#  'W615-Fit_HillSlope-Replicate_21',
#  'W615-Fit_LogAC50-Replicate_25',
#  'W530-Fit_R2-Replicate_25',
#  'Fold Increase @0.63 ug/ml Rep1',
#  'Std.Err(IC50)_1',
#  'Ratio-Fit_CurveClass-Replicate_12',
#  'W615-Fit_HillSlope-Replicate_5',
#  'W665-Fit_InfiniteActivity-Replicate_31',
#  'Efficacy-Replicate_55',
#  'W615-Fit_ZeroActivity-Replicate_35',
#  'W460-Fit_CurveClass',
#  'Fold Increase @2.5 ug/ml Rep2',
#  'W535-Fit_CurveClass-Replicate_26',
#  'W460-Fit_R2-Replicate_28',
#  'Activation @ 25 uM',
#  'W665-Fit_ZeroActivity-Replicate_20',
#  'W535-Fit_ZeroActivity-Replicate_1',
#  'W620-Fit_R2-Replicate_47',
#  'W615-Fit_R2-Replicate_13',
#  'W530-Max_Response-Replicate_5',
#  'W530-Fit_ZeroActivity-Replicate_8',
#  'W530-Fit_InfiniteActivity-Replicate_50',
#  'W535-Fit_LogAC50-Replicate_10',
#  'Fit_LogAC50-Replicate_46',
#  'W535-Max_Response-Replicate_35',
#  'W460-Fit_ZeroActivity-Replicate_20',
#  'W460-Fit_LogAC50-Replicate_32',
#  'W460-Fit_LogAC50-Replicate_30',
#  'W535-Fit_CurveClass-Replicate_9',
#  'W530-Fit_R2-Replicate_50',
#  'W460-Fit_R2-Replicate_40',
#  'W530-Fit_HillSlope-Replicate_6',
#  'Inhibition at 10 uM [4]',
#  'EC50_uM',
#  'W535-Fit_InfiniteActivity-Replicate_38',
#  'W620-Fit_ZeroActivity-Replicate_50',
#  'Fit_HillSlope-Replicate_48',
#  'Viability @ 1.875 uM',
#  'Ratio-Fit_R2-Replicate_53',
#  'W620-Fit_LogAC50-Replicate_47',
#  'Cell-Fit_ZeroActivity',
#  'W620-Fit_InfiniteActivity-Replicate_39',
#  'W665-Fit_R2-Replicate_5',
#  'W665-Fit_InfiniteActivity-Replicate_18',
#  'W535-Fit_InfiniteActivity-Replicate_24',
#  'Ratio-Max_Response-Replicate_10',
#  'W665-Fit_ZeroActivity-Replicate_36',
#  'W665-Fit_InfiniteActivity-Replicate_6',
#  '0.0001 uM POC  6.7 uM Cpd',
#  'W665-Fit_LogAC50',
#  'Efficacy-Replicate_54',
#  'Viability at 10 uM [2]',
#  'Fluorescence_Polarization-Max_Response',
#  'W460-Fit_InfiniteActivity-Replicate_16',
#  'W590-Fit_HillSlope-Replicate_8',
#  'Fit_LogAC50-Replicate_19',
#  'W615-Fit_InfiniteActivity-Replicate_26',
#  'W615-Fit_InfiniteActivity-Replicate_15',
#  '% Viability in Vero Cells @ 40 uM',
#  'W530-Max_Response-Replicate_15',
#  'Max_Response-Replicate_37',
#  'W615-Fit_LogAC50-Replicate_41',
#  'W590-Fit_LogAC50-Replicate_3',
#  'W460-Max_Response-Replicate_39',
#  'Inhibition at 10 uM {replicate 2}',
#  'W460-Fit_ZeroActivity-Replicate_25',
#  'W620-Fit_ZeroActivity-Replicate_35',
#  'W665-Max_Response-Replicate_47',
#  'W535-Fit_ZeroActivity-Replicate_21',
#  'W535-Fit_ZeroActivity-Replicate_37',
#  'Cell Viability at 0.0032 uM [1]',
#  'W530-Max_Response-Replicate_34',
#  'Ratio-Fit_ZeroActivity-Replicate_25',
#  'W665-Fit_HillSlope-Replicate_36',
#  'W460-Max_Response-Replicate_42',
#  'Ratio-Fit_LogAC50-Replicate_37',
#  '0.1 uM POC  6.7 uM Cpd',
#  'W590-Fit_R2-Replicate_1',
#  'W590-Fit_LogAC50-Replicate_16',
#  'W460-Max_Response-Replicate_53',
#  'Fit_LogAC50-Replicate_20',
#  'Max CPE Inhibition',
#  'W620-Fit_ZeroActivity-Replicate_40',
#  'W590-Fit_LogAC50-Replicate_36',
#  'Fold Increase @12.5 uM Rep1',
#  'Fit_InfiniteActivity-Replicate_33',
#  'IC50',
#  '0.8uM P Channel FOC',
#  'Max Inhibition',
#  'W615-Max_Response',
#  'W615-Fit_HillSlope-Replicate_33',
#  'Efficacy-Replicate_36',
#  'Surviving Cells at 2 uM [3]',
#  'Ratio-Fit_InfiniteActivity-Replicate_26',
#  'W615-Fit_LogAC50-Replicate_12',
#  'Fit_HillSlope',
#  'W615-Fit_ZeroActivity-Replicate_45',
#  'W620-Fit_CurveClass-Replicate_29',
#  'W665-Fit_HillSlope-Replicate_9',
#  'W535-Fit_R2-Replicate_6',
#  'W620-Fit_CurveClass-Replicate_4',
#  'W535-Fit_R2-Replicate_14',
#  'Pct Inhibition @ 3.125 uM Rep3',
#  'W665-Fit_LogAC50-Replicate_15',
#  'W530-Fit_LogAC50-Replicate_20',
#  'W615-Fit_ZeroActivity-Replicate_9',
#  'W535-Fit_HillSlope-Replicate_33',
#  'W615-Fit_InfiniteActivity-Replicate_25',
#  'W590-Fit_HillSlope-Replicate_24',
#  'W535-Fit_InfiniteActivity-Replicate_44',
#  'Red-Fit_LogAC50',
#  'W615-Max_Response-Replicate_36',
#  'W590-Fit_CurveClass-Replicate_30',
#  'W535-Fit_LogAC50-Replicate_6',
#  'W620-Fit_R2-Replicate_1',
#  '% CPE Inhibition @ 25 uM',
#  'W665-Fit_R2-Replicate_4',
#  'W535-Fit_HillSlope-Replicate_27',
#  'W530-Fit_HillSlope-Replicate_52',
#  'Ratio-Fit_InfiniteActivity-Replicate_34',
#  'Ratio-Fit_LogAC50-Replicate_15',
#  'Ratio-Fit_R2-Replicate_39',
#  'W665-Fit_ZeroActivity-Replicate_42',
#  'W590-Fit_R2-Replicate_4',
#  'Viability @ 0.059 uM',
#  '% Inhibition of H37Rv @ 0.39 uM',
#  'W590-Max_Response-Replicate_11',
#  'brca1-p1_activity-Fit_ZeroActivity',
#  'W620-Fit_InfiniteActivity-Replicate_7',
#  'W535-Max_Response-Replicate_11',
#  'Ratio-Fit_InfiniteActivity-Replicate_30',
#  'Ratio-Fit_ZeroActivity-Replicate_8',
#  'IC50 #1 max concentration',
#  'W615-Fit_InfiniteActivity-Replicate_42',
#  'W460-Fit_R2-Replicate_52',
#  '% Inhibition @ 0.78 uM',
#  'W590-Fit_R2-Replicate_6',
#  'StDev IC50',
#  'W615-Fit_LogAC50-Replicate_11',
#  'W460-Max_Response-Replicate_8',
#  'W615-Fit_InfiniteActivity-Replicate_22',
#  'Ratio-Fit_CurveClass-Replicate_7',
#  'W620-Fit_LogAC50-Replicate_51',
#  'W590-Fit_R2-Replicate_36',
#  'Viability at 0.01 uM [3]',
#  'RAWMCF_3.70_MICROM (3.70uM)',
#  'W530-Max_Response-Replicate_13',
#  'W615-Fit_ZeroActivity-Replicate_11',
#  'W665-Fit_ZeroActivity-Replicate_11',
#  'W530-Max_Response-Replicate_16',
#  'W530-Fit_CurveClass-Replicate_4',
#  'S0_(%)_TEST5',
#  'delta-Fit_R2',
#  'W620-Fit_InfiniteActivity-Replicate_48',
#  'Inhibition at 0.0001 uM [2]',
#  'W590-Fit_ZeroActivity-Replicate_31',
#  'Cell Viability at 1 uM [2]',
#  'W590-Fit_InfiniteActivity-Replicate_2',
#  'W530-Fit_R2-Replicate_10',
#  'W615-Max_Response-Replicate_33',
#  'Efficacy-Replicate_7',
#  'H37Rv PctInh @ 0.78 uM',
#  'Max_Concentration_uM_TEST5',
#  'W615-Fit_InfiniteActivity-Replicate_12',
#  'W620-Fit_InfiniteActivity-Replicate_16',
#  'W530-Max_Response-Replicate_50',
#  'Inhibition at 10 uM [3]',
#  'W590-Fit_R2-Replicate_24',
#  'Green-Fit_ZeroActivity',
#  'W460-Max_Response-Replicate_44',
#  'GFP-Fit_R2',
#  'Max_Concentration_uM_TEST2',
#  'Ratio-Fit_CurveClass-Replicate_20',
#  'Ratio-Fit_CurveClass-Replicate_38',
#  'UDG-Fit_CurveClass',
#  'Fit_CurveClass',
#  'W530-Fit_HillSlope-Replicate_48',
#  'W535-Fit_R2-Replicate_1',
#  'W590-Max_Response-Replicate_18',
#  'cells-Fit_ZeroActivity',
#  'Pct_Viability @0.78 uM Rep1',
#  'W615-Fit_InfiniteActivity-Replicate_28',
#  'W665-Fit_CurveClass-Replicate_13',
#  'W535-Fit_LogAC50-Replicate_1',
#  'IC50 #1 signal at 0.00152 microM',
#  'Total Fluorescence-Fit_ZeroActivity',
#  'W615-Fit_CurveClass-Replicate_8',
#  'W535-Max_Response-Replicate_25',
#  'Efficacy-Replicate_45',
#  'Ratio-Fit_HillSlope-Replicate_51',
#  'MS % Inhibition @ 50 uM',
#  'W460-Max_Response-Replicate_16',
#  '% Inhibition @ 0.05 uM',
#  '% Cell Viability @ 5 uM',
#  '% Cell Viability @ 0.313 uM',
#  'RAWMCF_33.33_MICROM (33.33uM) ',
#  'Ratio-Fit_InfiniteActivity-Replicate_23',
#  'W535-Fit_ZeroActivity-Replicate_27',
#  'W535-Fit_CurveClass-Replicate_16',
#  'W620-Fit_HillSlope-Replicate_13',
#  '0.0003 uM POC  20 uM Cpd',
#  'Fit_InfiniteActivity-Replicate_5',
#  'Inhibition at 0.00125 uM [2]',
#  'Fit_R2-Replicate_41',
#  'Ratio-Max_Response-Replicate_1',
#  'W590-Fit_HillSlope-Replicate_40',
#  'W620-Fit_ZeroActivity-Replicate_36',
#  'W530-Fit_R2-Replicate_16',
#  'Max_Response-Replicate_39',
#  'W620-Fit_CurveClass-Replicate_1',
#  'UDG-Fit_ZeroActivity',
#  'Fit_CurveClass-Replicate_5',
#  'W535-Fit_ZeroActivity-Replicate_4',
#  'W615-Fit_ZeroActivity-Replicate_40',
#  'W590-Fit_LogAC50-Replicate_29',
#  'Fit_R2-Replicate_43',
#  'Inhibition at 1.25 uM [3]',
#  'IC50 #1 blank standard deviation',
#  'RSQR',
#  'Percent Inhibition @ 1.56 uM',
#  'W665-Fit_InfiniteActivity-Replicate_22',
#  'Max_Activity_(%)_TEST4',
#  'W530-Fit_CurveClass-Replicate_42',
#  'W620-Fit_LogAC50-Replicate_50',
#  ...]

# %%
columns_matching[0].values.tolist()
# Out:
# ['W530-Activity at 60.96 uM-Replicate_22',
#  'W530-Activity at 24160.9 uM',
#  'Activity at 0.0001503265 uM',
#  'W460-Activity at 32.86 uM-Replicate_9',
#  'W530-Activity at 0.00120 uM-Replicate_3',
#  'W665-Activity at 0.582 uM-Replicate_7',
#  'Ratio-Activity at 3.154 uM-Replicate_26',
#  'W530-Activity at 0.056 uM-Replicate_46',
#  'Activity at 0.056 uM-Replicate_27',
#  'W590-Activity at 3.629 uM-Replicate_13',
#  'Activity at 73.33 uM-Replicate_26',
#  'Activity at 3.118 uM-Replicate_24',
#  'Donor-Activity at 2.300 uM',
#  'W590-Activity at 39.07 uM-Replicate_11',
#  'Activity at 23.57 uM-Replicate_5',
#  'Activity at 0.448 uM',
#  'Activity at 0.057 uM-Replicate_9',
#  'Activity at 0.756 uM-Replicate_43',
#  'Activity at 0.887 uM-Replicate_16',
#  'Ratio-Activity at 0.280 uM-Replicate_43',
#  'Ratio-Activity at 0.0002492385 uM-Replicate_4',
#  'Activity at 1.296 uM-Replicate_18',
#  'W460-Activity at 17.95 uM-Replicate_27',
#  'W535-Activity at 0.066 uM-Replicate_12',
#  'W460-Activity at 14.96 uM-Replicate_37',
#  'W460-Activity at 0.0000545573 uM-Replicate_3',
#  'Ratio-Activity at 0.00608 uM-Replicate_20',
#  'Activity at 154.2 uM-Replicate_8',
#  'W530-Activity at 81.11 uM-Replicate_4',
#  'W590-Activity at 0.0003047600 uM-Replicate_3',
#  'W530-Activity at 0.00223 uM-Replicate_31',
#  'Ratio-Activity at 0.00230 uM-Replicate_36',
#  'Activity at 0.00609 uM-Replicate_11',
#  'W530-Activity at 14.96 uM-Replicate_19',
#  'W530-Activity at 0.056 uM-Replicate_11',
#  'W530-Activity at 0.00107 uM-Replicate_50',
#  'Activity at 10.46 uM-Replicate_40',
#  'Ratio-Activity at 0.285 uM-Replicate_2',
#  'W460-Activity at 15.07 uM-Replicate_10',
#  'Activity at 0.191 uM',
#  'Ratio-Activity at 0.00107 uM-Replicate_43',
#  'Ratio-Activity at 2.670 uM-Replicate_48',
#  'W460-Activity at 6.948 uM-Replicate_34',
#  'Activity at 3.746 uM-Replicate_44',
#  'W460-Activity at 0.284 uM-Replicate_21',
#  'W665-Activity at 0.255 uM-Replicate_35',
#  'W665-Activity at 18.95 uM-Replicate_18',
#  'Activity at 4135.0 uM-Replicate_1',
#  'Ratio-Activity at 0.014 uM',
#  'Activity at 0.255 uM-Replicate_42',
#  'W530-Activity at 3.014 uM-Replicate_38',
#  'W460-Activity at 12996.2 uM',
#  'W590-Activity at 0.148 uM-Replicate_27',
#  'W460-Activity at 1.360 uM-Replicate_19',
#  'W530-Activity at 2.670 uM-Replicate_5',
#  'W665-Activity at 0.255 uM-Replicate_15',
#  'Activity at 0.0003864015 uM-Replicate_1',
#  'W665-Activity at 5.453 uM-Replicate_6',
#  'Ratio-Activity at 0.0009980156 uM-Replicate_37',
#  'W530-Activity at 60.96 uM-Replicate_10',
#  'Ratio-Activity at 18.95 uM-Replicate_12',
#  'RFP-Activity at 0.179 uM',
#  'W665-Activity at 0.00284 uM-Replicate_4',
#  'W460-Activity at 0.0002261535 uM-Replicate_5',
#  'Ratio-Activity at 0.00101 uM-Replicate_6',
#  'Ratio-Activity at 3.021 uM-Replicate_11',
#  '% Activity at 26.5 uM_first_point',
#  'W530-Activity at 0.00507 uM-Replicate_40',
#  'Ratio-Activity at 0.055 uM-Replicate_10',
#  'W530-Activity at 8.078 uM-Replicate_22',
#  'Activity at 3.264 uM-Replicate_28',
#  'Activity at 17.95 uM-Replicate_27',
#  'W530-Activity at 0.057 uM-Replicate_30',
#  'W590-Activity at 0.0000622235 uM-Replicate_1',
#  'Activity at 23.64 uM-Replicate_41',
#  'W530-Activity at 0.00513 uM-Replicate_25',
#  'Ratio-Activity at 0.00222 uM-Replicate_31',
#  'W460-Activity at 0.0005556937 uM-Replicate_17',
#  'Activity at 60.96 uM-Replicate_44',
#  'Activity at 1.863 uM',
#  'Ratio-Activity at 95.14 uM-Replicate_30',
#  'W535-Activity at 0.0001399083 uM-Replicate_3',
#  'Ratio-Activity at 29.14 uM-Replicate_51',
#  'Activity at 42.46 uM-Replicate_34',
#  'Ratio-Activity at 0.00496 uM-Replicate_18',
#  'W460-Activity at 32.62 uM-Replicate_38',
#  'W460-Activity at 17.95 uM-Replicate_11',
#  'W460-Activity at 0.291 uM-Replicate_26',
#  'W530-Activity at 0.125 uM-Replicate_10',
#  'W620-Activity at 0.114 uM-Replicate_51',
#  'W535-Activity at 1.635 uM-Replicate_28',
#  'Ratio-Activity at 0.0005152025 uM-Replicate_33',
#  'Activity at 1.843 uM-Replicate_1',
#  'W460-Activity at 1.391 uM-Replicate_2',
#  'Activity at 83.25 uM-Replicate_45',
#  'Activity_at_42uM',
#  'Ratio-Activity at 18.95 uM-Replicate_28',
#  'Ratio-Activity at 0.125 uM-Replicate_5',
#  'Activity at 18.95 uM-Replicate_17',
#  'Ratio-Activity at 0.057 uM-Replicate_31',
#  'Ratio-Activity at 0.00513 uM-Replicate_5',
#  'W460-Activity at 46230.0 uM-Replicate_3',
#  'Activity at 4.214 uM',
#  'Activity at 0.255 uM-Replicate_22',
#  'Ratio-Activity at 0.634 uM-Replicate_13',
#  'Activity at 0.194 uM-Replicate_9',
#  'Ratio-Activity at 0.030 uM-Replicate_46',
#  'W460-Activity at 29.14 uM-Replicate_4',
#  'Ratio-Activity at 0.00122 uM-Replicate_38',
#  'W530-Activity at 0.00101 uM-Replicate_7',
#  'Activity at 3.746 uM-Replicate_34',
#  'Ratio-Activity at 1.067 uM-Replicate_14',
#  'Total_fluorescence-Activity at 0.802 uM',
#  'W535-Activity at 3.629 uM-Replicate_17',
#  'Activity at 3.506 uM',
#  'W615-Activity at 0.013 uM-Replicate_48',
#  'W530-Activity at 8.078 uM-Replicate_38',
#  'W620-Activity at 14.00 uM-Replicate_38',
#  'Activity at 0.057 uM',
#  'W530-Activity at 76.83 uM-Replicate_21',
#  'W530-Activity at 0.0004938804 uM-Replicate_34',
#  'Activity at 23.57 uM-Replicate_12',
#  'W620-Activity at 0.114 uM-Replicate_42',
#  'Activity_at_18uM_(%)_TEST5',
#  'W530-Activity at 1.401 uM-Replicate_41',
#  'W530-Activity at 29.14 uM-Replicate_40',
#  'W530-Activity at 5.947 uM-Replicate_46',
#  'Activity at 78.95 uM-Replicate_7',
#  'Ratio-Activity at 29.14 uM-Replicate_35',
#  'Ratio-Activity at 0.011 uM-Replicate_30',
#  'Ratio-Activity at 0.637 uM-Replicate_2',
#  'Ratio-Activity at 95.14 uM-Replicate_25',
#  'W460-Activity at 5.947 uM-Replicate_29',
#  'W535-Activity at 0.735 uM-Replicate_4',
#  'W460-Activity at 0.066 uM-Replicate_38',
#  'W460-Activity at 1.434 uM-Replicate_42',
#  'W460-Activity at 5.947 uM-Replicate_34',
#  'AID-Activity at 0.368 uM',
#  'Activity at 0.00651 uM-Replicate_1',
#  'W530-Activity at 0.00434 uM-Replicate_3',
#  'Ratio-Activity at 0.0004987423 uM-Replicate_37',
#  'Activity at 5.764 uM',
#  'W530-Activity at 0.125 uM-Replicate_15',
#  'W590-Activity at 17.94 uM-Replicate_25',
#  'Ratio-Activity at 0.550 uM-Replicate_50',
#  'Activity at 3.112 uM-Replicate_5',
#  'W460-Activity at 0.127 uM-Replicate_30',
#  'W590-Activity at 0.00268 uM-Replicate_4',
#  'Activity at 316.0 uM',
#  'W460-Activity at 0.284 uM-Replicate_11',
#  'W530-Activity at 81.11 uM-Replicate_39',
#  'W460-Activity at 0.290 uM-Replicate_23',
#  'Ratio-Activity at 1.781 uM-Replicate_14',
#  'Activity at 0.057 uM-Replicate_37',
#  'W530-Activity at 15.10 uM-Replicate_11',
#  'W530-Activity at 2.701 uM-Replicate_39',
#  'Activity at 0.123 uM-Replicate_25',
#  'Activity at 0.703 uM',
#  'Activity at 94.82 uM-Replicate_12',
#  'Ratio-Activity at 0.132 uM-Replicate_33',
#  'Ratio-Activity at 58.48 uM-Replicate_31',
#  'W530-Activity at 0.00268 uM-Replicate_2',
#  'W530-Activity at 0.550 uM-Replicate_12',
#  'Ratio-Activity at 0.00223 uM-Replicate_17',
#  'Activity at 0.0007781017 uM-Replicate_1',
#  'Ratio-Activity at 3.629 uM-Replicate_20',
#  'W530-Activity at 0.00230 uM-Replicate_15',
#  'W530-Activity at 0.0009980281 uM-Replicate_34',
#  'W665-Activity at 0.114 uM-Replicate_5',
#  'W615-Activity at 92.41 uM-Replicate_33',
#  'Ratio-Activity at 62.57 uM-Replicate_32',
#  'Ratio-Activity at 3.173 uM-Replicate_24',
#  'W460-Activity at 0.611 uM-Replicate_25',
#  'Ratio-Activity at 0.00598 uM-Replicate_26',
#  'W460-Activity at 0.00107 uM-Replicate_44',
#  'W615-Activity at 0.068 uM-Replicate_17',
#  'W530-Activity at 0.00507 uM-Replicate_3',
#  'W530-Activity at 3.174 uM-Replicate_17',
#  'Activity at 1.403 uM-Replicate_49',
#  'Ratio-Activity at 0.055 uM-Replicate_37',
#  'W460-Activity at 0.132 uM-Replicate_52',
#  'Activity at 0.00141 uM-Replicate_37',
#  'Activity at 0.628 uM-Replicate_33',
#  'Ratio-Activity at 60.96 uM-Replicate_28',
#  'W530-Activity at 0.274 uM-Replicate_12',
#  'W460-Activity at 6.714 uM-Replicate_43',
#  'Activity at 115.4 uM-Replicate_3',
#  'Ratio-Activity at 0.107 uM',
#  'Ratio-Activity at 29.19 uM-Replicate_7',
#  'Activity at 3.975 uM-Replicate_9',
#  'W530-Activity at 0.068 uM-Replicate_13',
#  'Activity at 0.0005150359 uM-Replicate_17',
#  'W530-Activity at 62.39 uM-Replicate_16',
#  'W460-Activity at 182.0 uM',
#  'W460-Activity at 0.125 uM-Replicate_23',
#  'W530-Activity at 0.00268 uM-Replicate_39',
#  'W460-Activity at 27.01 uM-Replicate_45',
#  'W530-Activity at 0.030 uM-Replicate_45',
#  'Ratio-Activity at 0.0006197232 uM-Replicate_3',
#  'Activity at 0.00871 uM-Replicate_38',
#  'W530-Activity at 79.03 uM-Replicate_15',
#  'Ratio-Activity at 0.012 uM-Replicate_3',
#  'Activity at 8.078 uM-Replicate_17',
#  'Activity at 1.067 uM-Replicate_36',
#  'Activity at 0.0002720541 uM-Replicate_3',
#  'Activity at 1.685 uM-Replicate_8',
#  'Ratio-Activity at 79.05 uM-Replicate_39',
#  'W530-Activity at 0.285 uM-Replicate_4',
#  'Ratio-Activity at 0.127 uM-Replicate_32',
#  'W530-Activity at 0.00140 uM-Replicate_13',
#  'Ratio-Activity at 0.637 uM-Replicate_27',
#  'W665-Activity at 0.0006197232 uM-Replicate_7',
#  'Activity_at_0.0012uM_(%)',
#  'Ratio-Activity at 69.45 uM-Replicate_41',
#  'Activity at 0.00507 uM-Replicate_1',
#  'Activity at 1.685 uM-Replicate_48',
#  'brca1-p1_activity-Activity at 0.369 uM',
#  'W535-Activity at 0.329 uM-Replicate_38',
#  'Ratio-Activity at 0.00238 uM-Replicate_25',
#  'Ratio-Activity at 17.94 uM-Replicate_44',
#  'Ratio-Activity at 34.67 uM-Replicate_3',
#  'Ratio-Activity at 0.026 uM-Replicate_17',
#  'Activity at 70.87 uM-Replicate_49',
#  'W460-Activity at 0.0004931235 uM-Replicate_7',
#  'Activity at 0.330 uM-Replicate_41',
#  'W535-Activity at 3.629 uM-Replicate_10',
#  'Ratio-Activity at 0.624 uM-Replicate_22',
#  'W460-Activity at 2.701 uM-Replicate_20',
#  'Ratio-Activity at 0.126 uM-Replicate_44',
#  'Ratio-Activity at 0.610 uM-Replicate_39',
#  'W615-Activity at 0.030 uM-Replicate_8',
#  'W665-Activity at 0.00871 uM-Replicate_18',
#  'Ratio-Activity at 0.127 uM-Replicate_29',
#  'W530-Activity at 0.887 uM-Replicate_47',
#  'Activity at 70.87 uM-Replicate_16',
#  'Activity at 1.360 uM-Replicate_1',
#  'cells-Activity at 0.018 uM',
#  'W530-Activity at 0.00230 uM-Replicate_29',
#  'Ratio-Activity at 0.00608 uM-Replicate_3',
#  'W530-Activity at 0.057 uM-Replicate_20',
#  'Ratio-Activity at 0.00227 uM-Replicate_15',
#  'Ratio-Activity at 0.281 uM-Replicate_20',
#  'Activity at 0.634 uM-Replicate_3',
#  'Ratio-Activity at 76.83 uM-Replicate_47',
#  'Ratio-Activity at 76.83 uM-Replicate_5',
#  'W530-Activity at 60.96 uM-Replicate_38',
#  'W530-Activity at 83.24 uM-Replicate_44',
#  'W620-Activity at 0.00284 uM-Replicate_9',
#  'W590-Activity at 0.066 uM-Replicate_7',
#  'W460-Activity at 58.48 uM-Replicate_29',
#  'W460-Activity at 0.013 uM-Replicate_22',
#  'W460-Activity at 0.066 uM-Replicate_6',
#  'W460-Activity at 0.00426 uM-Replicate_47',
#  'W665-Activity at 0.00170 uM-Replicate_1',
#  'W460-Activity at 0.0002222558 uM-Replicate_5',
#  'W530-Activity at 5.947 uM-Replicate_11',
#  'W530-Activity at 0.00531 uM-Replicate_33',
#  'Activity at 70.35 uM-Replicate_4',
#  'Ratio-Activity at 0.00598 uM-Replicate_12',
#  'Activity_at_0.005uM_(%)_TEST2',
#  'Activity at 1.360 uM-Replicate_17',
#  'Activity at 1.403 uM-Replicate_5',
#  'W530-Activity at 6.976 uM-Replicate_34',
#  'Activity at 46.02 uM',
#  'W460-Activity at 83.25 uM-Replicate_32',
#  'Activity at 18.12 uM-Replicate_22',
#  'Activity at 70.35 uM-Replicate_11',
#  'Activity at 0.00820 uM',
#  'W460-Activity at 0.290 uM-Replicate_27',
#  'W615-Activity at 0.349 uM-Replicate_15',
#  'W530-Activity at 14.95 uM-Replicate_37',
#  'W665-Activity at 3087.0 uM-Replicate_3',
#  'W460-Activity at 0.00434 uM-Replicate_43',
#  'W615-Activity at 0.068 uM-Replicate_46',
#  'Ratio-Activity at 6.976 uM-Replicate_26',
#  'Activity at 0.0004987423 uM-Replicate_42',
#  'W460-Activity at 0.291 uM-Replicate_32',
#  'Activity at 5.110 uM',
#  'Activity at 17.95 uM-Replicate_1',
#  'Ratio-Activity at 0.00229 uM-Replicate_46',
#  'W665-Activity at 0.582 uM-Replicate_11',
#  'Activity at 3.975 uM-Replicate_12',
#  'Ratio-Activity at 0.628 uM-Replicate_38',
#  'Activity at 0.00212 uM-Replicate_40',
#  'Activity at 5.430 uM-Replicate_10',
#  'Ratio-Activity at 1.674 uM-Replicate_12',
#  'Activity at 70.87 uM-Replicate_17',
#  'W530-Activity at 6.973 uM-Replicate_35',
#  'W530-Activity at 62.57 uM-Replicate_49',
#  'W665-Activity at 0.582 uM-Replicate_46',
#  'Fed-Activity at 46.10 uM',
#  'W620-Activity at 70.87 uM-Replicate_47',
#  'W620-Activity at 0.00284 uM-Replicate_2',
#  'Ratio-Activity at 0.00101 uM-Replicate_24',
#  'Activity at 8.387 uM-Replicate_9',
#  'Ratio-Activity at 872.4 uM-Replicate_2',
#  'W615-Activity at 92.41 uM-Replicate_5',
#  'Ratio-Activity at 6.711 uM-Replicate_23',
#  'Activity at 0.017 uM-Replicate_50',
#  'W530-Activity at 3.014 uM-Replicate_39',
#  'W535-Activity at 83.22 uM-Replicate_24',
#  'Activity at 34.33 uM-Replicate_10',
#  'Ratio-Activity at 0.0005150359 uM-Replicate_17',
#  'W460-Activity at 7.040 uM-Replicate_44',
#  'W460-Activity at 0.011 uM-Replicate_13',
#  'Ratio-Activity at 0.00101 uM-Replicate_16',
#  'W530-Activity at 0.057 uM-Replicate_27',
#  'Ratio-Activity at 2.716 uM-Replicate_40',
#  'W620-Activity at 1.781 uM-Replicate_49',
#  'Ratio-Activity at 35.30 uM-Replicate_8',
#  'W530-Activity at 0.330 uM-Replicate_35',
#  'W460-Activity at 0.00497 uM-Replicate_41',
#  'W530-Activity at 62.57 uM-Replicate_19',
#  'W590-Activity at 0.00598 uM-Replicate_37',
#  'Activity at 95.67 uM-Replicate_8',
#  'Ratio-Activity at 0.026 uM-Replicate_3',
#  'Ratio-Activity at 15.84 uM-Replicate_5',
#  'W460-Activity at 0.00231 uM-Replicate_26',
#  'Activity at 15.76 uM-Replicate_36',
#  'W590-Activity at 0.030 uM-Replicate_41',
#  'Activity at 0.290 uM-Replicate_5',
#  'W665-Activity at 42.46 uM-Replicate_23',
#  'Activity at 8.080 uM-Replicate_7',
#  'W460-Activity at 0.123 uM-Replicate_27',
#  'W530-Activity at 0.610 uM-Replicate_29',
#  'Ratio-Activity at 73.33 uM-Replicate_5',
#  'W460-Activity at 0.00226 uM-Replicate_31',
#  'Ratio-Activity at 2.701 uM-Replicate_6',
#  'Activity at 8.390 uM-Replicate_14',
#  'Activity at 0.763 uM-Replicate_4',
#  'Ratio-Activity at 7.009 uM-Replicate_3',
#  'W620-Activity at 70.87 uM-Replicate_39',
#  'Activity at 94.82 uM-Replicate_3',
#  'W460-Activity at 0.274 uM-Replicate_17',
#  'Activity at 13.22 uM-Replicate_4',
#  'Activity at 3.020 uM-Replicate_14',
#  'Activity at 73.33 uM-Replicate_52',
#  'W460-Activity at 0.00268 uM-Replicate_19',
#  'Activity at 3.118 uM-Replicate_4',
#  'W460-Activity at 69.45 uM-Replicate_31',
#  'Activity at 0.00657 uM-Replicate_11',
#  'W615-Activity at 0.013 uM-Replicate_40',
#  'Activity at 3.630 uM-Replicate_6',
#  'Activity at 3.020 uM-Replicate_10',
#  'Activity at 3.264 uM-Replicate_46',
#  'Ratio-Activity at 8.300 uM-Replicate_10',
#  'Activity at 0.887 uM-Replicate_40',
#  'Ratio-Activity at 0.00122 uM-Replicate_23',
#  'W460-Activity at 15.84 uM-Replicate_2',
#  'W530-Activity at 1.415 uM-Replicate_44',
#  'Activity at 0.0006607872 uM-Replicate_13',
#  'Activity at 0.0006607872 uM-Replicate_45',
#  'W530-Activity at 0.00432 uM-Replicate_45',
#  'W530-Activity at 0.628 uM-Replicate_17',
#  'Activity at 0.0006237638 uM-Replicate_3',
#  'Activity at 0.0003041660 uM-Replicate_2',
#  'Activity at 66.78 uM-Replicate_11',
#  'Ratio-Activity at 0.00598 uM-Replicate_42',
#  'W460-Activity at 3.319 uM-Replicate_13',
#  'W590-Activity at 0.329 uM-Replicate_9',
#  'Ratio-Activity at 8.386 uM-Replicate_37',
#  'W530-Activity at 0.00496 uM-Replicate_3',
#  'Ratio-Activity at 1.225 uM-Replicate_31',
#  'W460-Activity at 0.280 uM-Replicate_13',
#  'W530-Activity at 3.095 uM-Replicate_17',
#  'Ratio-Activity at 15.11 uM-Replicate_4',
#  'Ratio-Activity at 34.67 uM-Replicate_26',
#  'Ratio-Activity at 5.947 uM-Replicate_36',
#  'Ratio-Activity at 42.46 uM-Replicate_46',
#  'Ratio-Activity at 0.550 uM-Replicate_32',
#  'Activity at 0.085 uM-Replicate_49',
#  'Activity at 92.41 uM-Replicate_41',
#  'W460-Activity at 39.10 uM-Replicate_8',
#  'W460-Activity at 3.095 uM-Replicate_3',
#  'Activity at 6.973 uM-Replicate_47',
#  'W530-Activity at 0.00507 uM-Replicate_9',
#  'W460-Activity at 2.701 uM-Replicate_39',
#  'Ratio-Activity at 0.0006613093 uM-Replicate_32',
#  'W530-Activity at 6.976 uM-Replicate_40',
#  'W460-Activity at 1.391 uM-Replicate_12',
#  'W460-Activity at 3.198 uM-Replicate_41',
#  'W615-Activity at 8.386 uM-Replicate_22',
#  'Ratio-Activity at 2.670 uM-Replicate_47',
#  'Ratio-Activity at 32.62 uM-Replicate_33',
#  'W460-Activity at 32.86 uM-Replicate_22',
#  'W530-Activity at 0.148 uM-Replicate_1',
#  'W460-Activity at 0.0004949824 uM-Replicate_43',
#  'W460-Activity at 0.00170 uM-Replicate_3',
#  'Activity at 3.630 uM-Replicate_46',
#  'Activity at 0.123 uM-Replicate_42',
#  '% Activity at 0.368 uM_second_point',
#  'Activity at 0.00651 uM-Replicate_20',
#  'Ratio-Activity at 0.066 uM-Replicate_20',
#  'W460-Activity at 3.198 uM-Replicate_35',
#  'Ratio-Activity at 15.76 uM-Replicate_13',
#  'CBG-Activity at 0.369 uM',
#  'Activity_at_12uM',
#  'Ratio-Activity at 0.00120 uM-Replicate_21',
#  'W530-Activity at 0.00505 uM-Replicate_9',
#  'Activity at 0.030 uM-Replicate_17',
#  'W460-Activity at 3.014 uM-Replicate_20',
#  'Activity at 0.255 uM-Replicate_18',
#  'Ratio-Activity at 3.154 uM-Replicate_32',
#  'W530-Activity at 0.012 uM-Replicate_42',
#  'Ratio-Activity at 79.15 uM-Replicate_22',
#  'Activity at 0.330 uM-Replicate_4',
#  'Ratio-Activity at 76.83 uM-Replicate_25',
#  'W530-Activity at 0.00223 uM-Replicate_15',
#  'W460-Activity at 4135.0 uM-Replicate_1',
#  'W530-Activity at 0.132 uM-Replicate_16',
#  'W460-Activity at 0.00140 uM-Replicate_11',
#  'W460-Activity at 0.624 uM-Replicate_35',
#  'Ratio-Activity at 0.128 uM-Replicate_20',
#  'Activity at 0.0006197192 uM-Replicate_39',
#  'W615-Activity at 0.349 uM-Replicate_45',
#  'W460-Activity at 15.11 uM-Replicate_30',
#  'W530-Activity at 0.025 uM-Replicate_18',
#  'W665-Activity at 0.255 uM-Replicate_8',
#  'W460-Activity at 6.976 uM-Replicate_35',
#  'Ratio-Activity at 1.635 uM-Replicate_32',
#  'Activity at 0.00497 uM-Replicate_11',
#  'Activity at 1.156 uM',
#  'W530-Activity at 1.391 uM-Replicate_7',
#  'W460-Activity at 79.14 uM-Replicate_34',
#  'W530-Activity at 6.973 uM-Replicate_38',
#  'Ratio-Activity at 0.153 uM-Replicate_18',
#  'Activity at 154.2 uM-Replicate_37',
#  'Activity at 0.0002686721 uM',
#  'W460-Activity at 0.00120 uM-Replicate_14',
#  'Ratio-Activity at 83.21 uM-Replicate_36',
#  'Ratio-Activity at 0.00142 uM-Replicate_3',
#  'Ratio-Activity at 0.349 uM-Replicate_7',
#  'W530-Activity at 1.360 uM-Replicate_21',
#  'Activity at 0.127 uM',
#  'W460-Activity at 0.123 uM-Replicate_39',
#  'Activity at 0.349 uM-Replicate_8',
#  'RFP-Activity at 0.011 uM',
#  'Activity at 6.973 uM-Replicate_17',
#  'Activity at 9246.0 uM-Replicate_1',
#  'W665-Activity at 0.022 uM-Replicate_30',
#  'Activity at 8.078 uM-Replicate_25',
#  'W530-Activity at 0.291 uM-Replicate_13',
#  'W460-Activity at 81.11 uM-Replicate_26',
#  'Activity at 52.95 uM-Replicate_6',
#  'W530-Activity at 0.00101 uM-Replicate_37',
#  'W530-Activity at 0.0001216490 uM-Replicate_3',
#  'Ratio-Activity at 0.00608 uM-Replicate_6',
#  'Ratio-Activity at 154.2 uM-Replicate_9',
#  'W460-Activity at 3.021 uM-Replicate_24',
#  'W530-Activity at 15.07 uM-Replicate_33',
#  'Activity at 0.00598 uM-Replicate_35',
#  'Activity at 0.435 uM-Replicate_22',
#  '% Activity at 6.1875 uM',
#  'Ratio-Activity at 14.00 uM-Replicate_8',
#  'W530-Activity at 0.735 uM-Replicate_14',
#  'W665-Activity at 92.41 uM-Replicate_4',
#  'Ratio-Activity at 17.94 uM-Replicate_34',
#  'Activity at 0.0005152588 uM-Replicate_4',
#  'W460-Activity at 0.026 uM-Replicate_31',
#  'Activity at 0.152 uM-Replicate_38',
#  'Activity at 1.330 uM-Replicate_31',
#  'Ratio-Activity at 0.025 uM-Replicate_15',
#  'W535-Activity at 1.635 uM-Replicate_44',
#  'W460-Activity at 29.19 uM-Replicate_14',
#  'Ratio-Activity at 62.57 uM-Replicate_37',
#  'W460-Activity at 62.57 uM-Replicate_52',
#  'RFP-Activity at 0.360 uM',
#  'W665-Activity at 0.00871 uM-Replicate_27',
#  'Activity at 2.037 uM-Replicate_14',
#  'W620-Activity at 0.114 uM-Replicate_5',
#  'W460-Activity at 0.0005839002 uM-Replicate_38',
#  'Activity at 0.056 uM',
#  'Activity at 0.0001704127 uM',
#  'Activity at 0.00187 uM',
#  'Activity at 0.0006197192 uM-Replicate_1',
#  'Activity_at_0.00075uM_(%)_TEST2',
#  'W530-Activity at 0.0005106135 uM-Replicate_34',
#  'W460-Activity at 0.057 uM',
#  'W460-Activity at 0.066 uM-Replicate_2',
#  'Activity at 1.330 uM-Replicate_49',
#  'W530-Activity at 0.0004938804 uM-Replicate_6',
#  'Activity at 0.00497 uM-Replicate_12',
#  'Ratio-Activity at 0.00227 uM-Replicate_32',
#  'W460-Activity at 0.057 uM-Replicate_35',
#  'Activity at 94.82 uM-Replicate_24',
#  'Ratio-Activity at 0.0004939798 uM-Replicate_1',
#  'Ratio-Activity at 0.00268 uM-Replicate_36',
#  'W530-Activity at 0.00507 uM-Replicate_33',
#  'Activity at 0.274 uM-Replicate_30',
#  'Ratio-Activity at 0.014 uM-Replicate_17',
#  'W460-Activity at 0.00531 uM-Replicate_14',
#  'W460-Activity at 0.011 uM-Replicate_7',
#  'Ratio-Activity at 3.725 uM-Replicate_30',
#  'Activity at 28.54 uM-Replicate_28',
#  'W530-Activity at 0.637 uM-Replicate_5',
#  'W460-Activity at 0.00516 uM-Replicate_19',
#  'Activity at 8.077 uM-Replicate_2',
#  'Activity at 0.085 uM-Replicate_9',
#  'Activity at 0.193 uM-Replicate_2',
#  'W530-Activity at 6.948 uM-Replicate_46',
#  'Ratio-Activity at 0.00294 uM',
#  'Activity at 0.0006609925 uM-Replicate_39',
#  'W460-Activity at 0.0005150359 uM-Replicate_1',
#  'Activity at 0.00223 uM-Replicate_21',
#  'W460-Activity at 0.125 uM-Replicate_37',
#  'Activity at 94.82 uM-Replicate_13',
#  'Activity_at_0.68uM_(%)_TEST3',
#  'W530-Activity at 1.422 uM-Replicate_10',
#  'W460-Activity at 29.14 uM-Replicate_16',
#  'Activity at 3.393 uM',
#  'W460-Activity at 79.15 uM-Replicate_31',
#  'Activity at 0.0005955401 uM-Replicate_7',
#  'Activity at 0.00120 uM-Replicate_31',
#  'W535-Activity at 0.0006614272 uM-Replicate_15',
#  'fed-Activity at 25.70 uM',
#  'W535-Activity at 8.077 uM-Replicate_27',
#  'W530-Activity at 0.126 uM-Replicate_4',
#  'W535-Activity at 39.07 uM-Replicate_18',
#  'W530-Activity at 0.274 uM-Replicate_19',
#  'Activity at 8.390 uM-Replicate_50',
#  'Ratio-Activity at 0.00426 uM-Replicate_19',
#  'Ratio-Activity at 5.947 uM-Replicate_31',
#  'Activity at 0.0007577384 uM-Replicate_12',
#  'Activity at 23.64 uM-Replicate_35',
#  'W460-Activity at 0.550 uM-Replicate_36',
#  'Ratio-Activity at 0.887 uM-Replicate_30',
#  'Ratio-Activity at 15.76 uM-Replicate_25',
#  'Activity at 1.859 uM-Replicate_8',
#  'AID-Activity at 9.200 uM',
#  'Ratio-Activity at 81.11 uM-Replicate_38',
#  'W620-Activity at 3087.0 uM-Replicate_2',
#  'W530-Activity at 2.714 uM-Replicate_8',
#  'Activity at 0.0007728037 uM-Replicate_49',
#  'W535-Activity at 0.030 uM-Replicate_44',
#  'Ratio-Activity at 0.00434 uM-Replicate_6',
#  'W590-Activity at 95.27 uM-Replicate_12',
#  'W530-Activity at 3.112 uM-Replicate_42',
#  'W615-Activity at 0.00170 uM-Replicate_46',
#  'W530-Activity at 0.0005064679 uM-Replicate_25',
#  'W530-Activity at 27.01 uM-Replicate_12',
#  'Activity at 78.83 uM-Replicate_15',
#  'Activity at 0.014 uM-Replicate_51',
#  'Activity at 0.0005152025 uM-Replicate_21',
#  'Ratio-Activity at 58.48 uM-Replicate_37',
#  'Activity at 42.46 uM-Replicate_9',
#  'W530-Activity at 2.670 uM-Replicate_16',
#  'Ratio-Activity at 0.00140 uM-Replicate_39',
#  'W460-Activity at 35.30 uM-Replicate_38',
#  'Ratio-Activity at 0.00102 uM-Replicate_47',
#  'W460-Activity at 29.18 uM-Replicate_19',
#  'W530-Activity at 0.126 uM-Replicate_1',
#  'W460-Activity at 0.025 uM-Replicate_50',
#  'W460-Activity at 1.415 uM-Replicate_30',
#  'W460-Activity at 0.610 uM-Replicate_31',
#  'W530-Activity at 0.148 uM-Replicate_42',
#  'Activity at 6.950 uM-Replicate_28',
#  'Ratio-Activity at 0.329 uM-Replicate_21',
#  'Activity at 1.330 uM-Replicate_7',
#  'Activity at 1.401 uM-Replicate_41',
#  'Ratio-Activity at 79.15 uM-Replicate_46',
#  'W590-Activity at 0.030 uM-Replicate_11',
#  'Ratio-Activity at 73.33 uM-Replicate_47',
#  'Ratio-Activity at 0.0004987423 uM-Replicate_11',
#  'W665-Activity at 14.00 uM-Replicate_26',
#  'Ratio-Activity at 0.0001158387 uM-Replicate_3',
#  'W530-Activity at 2.714 uM-Replicate_21',
#  'Ratio-Activity at 0.275 uM-Replicate_31',
#  'W535-Activity at 3.629 uM-Replicate_5',
#  'Activity at 10.21 uM-Replicate_2',
#  'Activity at 0.628 uM-Replicate_9',
#  'Ratio-Activity at 15.11 uM-Replicate_2',
#  'Activity at 3.831 uM-Replicate_11',
#  'W460-Activity at 0.00104 uM-Replicate_36',
#  'Ratio-Activity at 56.99 uM-Replicate_19',
#  'W530-Activity at 0.281 uM-Replicate_8',
#  'W530-Activity at 0.00140 uM-Replicate_10',
#  'W530-Activity at 0.0005152025 uM-Replicate_39',
#  'W535-Activity at 17.94 uM-Replicate_6',
#  'Activity at 94.82 uM-Replicate_30',
#  'W460-Activity at 76.84 uM-Replicate_55',
#  'W530-Activity at 0.0004949824 uM-Replicate_15',
#  'Ratio-Activity at 1.674 uM-Replicate_20',
#  'Ratio-Activity at 15.07 uM-Replicate_29',
#  'Activity at 0.00171 uM-Replicate_11',
#  'W460-Activity at 0.00497 uM-Replicate_15',
#  'W460-Activity at 3.198 uM-Replicate_4',
#  'W665-Activity at 0.022 uM-Replicate_36',
#  'W530-Activity at 28.54 uM-Replicate_44',
#  'Activity at 34.33 uM-Replicate_51',
#  'W530-Activity at 3.507 uM',
#  'Activity at 0.582 uM-Replicate_32',
#  'W460-Activity at 35.30 uM-Replicate_40',
#  'Activity at 1.330 uM-Replicate_1',
#  'W530-Activity at 15.01 uM-Replicate_22',
#  'W615-Activity at 0.0006197232 uM-Replicate_43',
#  'W530-Activity at 0.125 uM-Replicate_1',
#  'Activity at 0.338 uM-Replicate_13',
#  'Ratio-Activity at 73.33 uM-Replicate_32',
#  'Activity at 0.350 uM-Replicate_11',
#  'Activity at 28.54 uM-Replicate_32',
#  'Ratio-Activity at 0.00229 uM-Replicate_6',
#  'Activity at 14.00 uM-Replicate_17',
#  'Activity at 2.205 uM',
#  'W530-Activity at 78.83 uM-Replicate_50',
#  'Ratio-Activity at 0.00170 uM-Replicate_29',
#  'Ratio-Activity at 2.716 uM-Replicate_7',
#  'Activity at 0.0003002588 uM-Replicate_1',
#  'Ratio-Activity at 0.123 uM-Replicate_22',
#  'Ratio-Activity at 0.281 uM-Replicate_32',
#  'W530-Activity at 0.055 uM-Replicate_29',
#  'W530-Activity at 0.550 uM-Replicate_47',
#  'Activity at 15.11 uM-Replicate_16',
#  'W530-Activity at 0.026 uM-Replicate_22',
#  'W460-Activity at 14.96 uM-Replicate_16',
#  'Ratio-Activity at 0.0009980156 uM-Replicate_41',
#  'Ratio-Activity at 58.48 uM-Replicate_42',
#  'W615-Activity at 0.0000060039 uM-Replicate_1',
#  'W530-Activity at 79.11 uM-Replicate_5',
#  'W530-Activity at 3.014 uM-Replicate_30',
#  'W530-Activity at 0.611 uM-Replicate_25',
#  'Ratio-Activity at 0.00284 uM-Replicate_11',
#  'Ratio-Activity at 14.00 uM-Replicate_2',
#  'Nrf2-Activity at 0.369 uM',
#  'W460-Activity at 0.330 uM-Replicate_39',
#  'Activity at 8.553 uM-Replicate_14',
#  'Activity at 0.00366 uM',
#  'W460-Activity at 0.642 uM-Replicate_38',
#  'Activity at 1.330 uM-Replicate_23',
#  'Ratio-Activity at 0.280 uM-Replicate_28',
#  'W530-Activity at 0.153 uM-Replicate_4',
#  'W530-Activity at 0.055 uM-Replicate_40',
#  'Activity at 0.193 uM-Replicate_17',
#  'W530-Activity at 0.059 uM-Replicate_25',
#  'Ratio-Activity at 15.01 uM-Replicate_1',
#  'Ratio-Activity at 0.00522 uM-Replicate_3',
#  'W460-Activity at 3.095 uM-Replicate_18',
#  'Ratio-Activity at 0.123 uM-Replicate_24',
#  'Ratio-Activity at 14.95 uM-Replicate_15',
#  'Ratio-Activity at 0.025 uM-Replicate_10',
#  'W530-Activity at 0.290 uM-Replicate_16',
#  'Activity at 0.00212 uM-Replicate_46',
#  'Activity_at_0.0038uM_(%)_TEST3',
#  'W535-Activity at 0.030 uM-Replicate_34',
#  'Ratio-Activity at 0.051 uM-Replicate_36',
#  'W620-Activity at 1.781 uM-Replicate_44',
#  'W590-Activity at 8.077 uM-Replicate_20',
#  'Ratio-Activity at 0.00496 uM-Replicate_8',
#  'Ratio-Activity at 3.173 uM-Replicate_9',
#  'W460-Activity at 17.95 uM-Replicate_29',
#  'Activity at 0.349 uM-Replicate_19',
#  'W530-Activity at 6.948 uM-Replicate_33',
#  'Ratio-Activity at 0.00120 uM-Replicate_32',
#  'Activity at 28.54 uM-Replicate_33',
#  'Activity at 0.00434 uM-Replicate_47',
#  'W530-Activity at 0.291 uM-Replicate_8',
#  'Activity at 14.96 uM-Replicate_3',
#  'Ratio-Activity at 5.947 uM-Replicate_37',
#  'Ratio-Activity at 79.05 uM-Replicate_37',
#  'W535-Activity at 0.030 uM-Replicate_2',
#  'Activity at 8.358 uM-Replicate_16',
#  'W460-Activity at 3.154 uM-Replicate_46',
#  'Activity at 0.00598 uM-Replicate_44',
#  'W665-Activity at 0.00284 uM-Replicate_11',
#  'Ratio-Activity at 0.0000909942 uM-Replicate_2',
#  'Activity at 27.01 uM-Replicate_3',
#  'W460-Activity at 0.0002222558 uM-Replicate_1',
#  'Activity at 0.00609 uM-Replicate_43',
#  'W530-Activity at 0.0005478319 uM-Replicate_41',
#  'W530-Activity at 15.11 uM-Replicate_43',
#  'Ratio-Activity at 0.00608 uM-Replicate_35',
#  'Activity at 0.038 uM-Replicate_11',
#  'Activity at 83.25 uM-Replicate_39',
#  'W460-Activity at 78.83 uM-Replicate_38',
#  'W460-Activity at 0.066 uM-Replicate_47',
#  'Ratio-Activity at 3.319 uM-Replicate_9',
#  'Red-Activity at 0.00368 uM',
#  'W530-Activity at 0.735 uM-Replicate_30',
#  'Ratio-Activity at 0.00230 uM-Replicate_45',
#  'Ratio-Activity at 0.00505 uM-Replicate_4',
#  'W530-Activity at 62.39 uM-Replicate_31',
#  'Activity at 0.451 uM',
#  'Activity at 8.386 uM-Replicate_47',
#  'W530-Activity at 1.360 uM-Replicate_23',
#  'Activity at 0.00527 uM-Replicate_3',
#  '% Activity at 47.111 uM_first_point',
#  'Ratio-Activity at 2.714 uM-Replicate_30',
#  'Ratio-Activity at 15.07 uM-Replicate_17',
#  'W530-Activity at 0.00141 uM-Replicate_49',
#  'W460-Activity at 0.611 uM-Replicate_45',
#  'Activity at 0.350 uM-Replicate_38',
#  'Activity at 83.25 uM-Replicate_3',
#  'W530-Activity at 0.0000036780 uM-Replicate_2',
#  'Activity at 3.112 uM-Replicate_47',
#  'W530-Activity at 3.021 uM-Replicate_11',
#  'Activity_at_12uM_(%)_TEST3',
#  'Ratio-Activity at 35.48 uM-Replicate_49',
#  'Activity at 1.80uM',
#  'W460-Activity at 0.123 uM-Replicate_30',
#  '% Activity at 0.15625 uM_third_point',
#  'W530-Activity at 2.714 uM-Replicate_9',
#  'Activity at 96.01 uM',
#  'W460-Activity at 5.947 uM-Replicate_37',
#  'W460-Activity at 0.711 uM',
#  'Ratio-Activity at 8.300 uM-Replicate_33',
#  'W530-Activity at 0.0005478319 uM-Replicate_32',
#  'W665-Activity at 0.349 uM-Replicate_27',
#  'Activity at 0.767 uM-Replicate_5',
#  'Ratio-Activity at 0.00497 uM-Replicate_40',
#  'W590-Activity at 8.077 uM-Replicate_29',
#  'Activity at 52.95 uM-Replicate_36',
#  'W665-Activity at 0.051 uM-Replicate_31',
#  'Activity at 0.00298 uM',
#  'W460-Activity at 79.15 uM-Replicate_1',
#  'W590-Activity at 0.0006614272 uM-Replicate_38',
#  'Activity at 0.00651 uM-Replicate_15',
#  'W530-Activity at 3.112 uM-Replicate_45',
#  'W460-Activity at 58.48 uM-Replicate_4',
#  'W615-Activity at 92.41 uM-Replicate_23',
#  'Activity at 0.00284 uM-Replicate_3',
#  'W530-Activity at 3.267 uM-Replicate_8',
#  'W530-Activity at 15.84 uM-Replicate_6',
#  'Activity at 1.066 uM-Replicate_16',
#  'Ratio-Activity at 18.95 uM-Replicate_24',
#  'Ratio-Activity at 0.014 uM-Replicate_6',
#  'W535-Activity at 0.013 uM-Replicate_25',
#  'W460-Activity at 0.634 uM-Replicate_24',
#  'W460-Activity at 62.39 uM-Replicate_46',
#  'Activity at 18.95 uM-Replicate_9',
#  'Ratio-Activity at 8.475 uM',
#  'Ratio-Activity at 14.00 uM-Replicate_42',
#  'Ratio-Activity at 0.582 uM-Replicate_20',
#  'Ratio-Activity at 79.05 uM-Replicate_17',
#  'CBR-Activity at 0.015 uM',
#  'W535-Activity at 0.030 uM-Replicate_24',
#  'Activity at 0.030 uM-Replicate_38',
#  'Ratio-Activity at 0.0000047774 uM-Replicate_1',
#  'Activity at 3.112 uM-Replicate_3',
#  'Activity at 0.191 uM-Replicate_51',
#  'Activity at 0.0006605434 uM-Replicate_31',
#  'W590-Activity at 0.00120 uM-Replicate_28',
#  'W460-Activity at 1.391 uM-Replicate_22',
#  'W460-Activity at 32.62 uM-Replicate_42',
#  'W460-Activity at 0.00238 uM-Replicate_2',
#  'W530-Activity at 1.360 uM-Replicate_20',
#  'W535-Activity at 39.07 uM-Replicate_15',
#  'W460-Activity at 0.349 uM-Replicate_5',
#  'Ratio-Activity at 0.0005152025 uM-Replicate_41',
#  'W620-Activity at 3087.0 uM-Replicate_1',
#  'W530-Activity at 0.00140 uM-Replicate_44',
#  'W460-Activity at 0.00101 uM-Replicate_13',
#  'W460-Activity at 0.0000514202 uM-Replicate_2',
#  'W460-Activity at 1.357 uM-Replicate_12',
#  'Activity at 30.72 uM-Replicate_9',
#  'W460-Activity at 0.00531 uM-Replicate_24',
#  'W530-Activity at 14.95 uM-Replicate_36',
#  'W530-Activity at 1.357 uM-Replicate_31',
#  'Fed-Activity at 0.369 uM',
#  'W460-Activity at 18.95 uM-Replicate_6',
#  'Activity at 1.073 uM-Replicate_7',
#  'Donor 2 Activity at 0.09uM',
#  'W530-Activity at 62.57 uM-Replicate_40',
#  'Activity at 0.342 uM-Replicate_13',
#  'W530-Activity at 0.284 uM-Replicate_13',
#  'W530-Activity at 0.624 uM-Replicate_20',
#  'Activity at 1.330 uM-Replicate_15',
#  'W535-Activity at 0.148 uM-Replicate_16',
#  'W535-Activity at 3.629 uM-Replicate_42',
#  'W620-Activity at 14.00 uM-Replicate_40',
#  'W460-Activity at 0.00507 uM-Replicate_43',
#  'W460-Activity at 62.57 uM-Replicate_21',
#  'W530-Activity at 1.415 uM-Replicate_16',
#  'Ratio-Activity at 0.610 uM-Replicate_8',
#  'Ratio-Activity at 58.48 uM-Replicate_34',
#  'Activity at 0.887 uM-Replicate_3',
#  'Activity at 162.3 uM',
#  'Ratio-Activity at 0.00229 uM-Replicate_43',
#  'W460-Activity at 0.0009980156 uM-Replicate_9',
#  'W460-Activity at 0.126 uM-Replicate_16',
#  'Activity at 0.00510 uM-Replicate_8',
#  'Activity at 0.057 uM-Replicate_31',
#  'W460-Activity at 29.18 uM-Replicate_39',
#  'W530-Activity at 0.735 uM-Replicate_8',
#  'Activity at 0.0003864015 uM-Replicate_17',
#  'Activity at 0.0007728037 uM-Replicate_20',
#  'FP-Activity at 81.19 uM',
#  'W615-Activity at 0.068 uM-Replicate_4',
#  'Activity at 0.051 uM-Replicate_39',
#  'W530-Activity at 3.267 uM-Replicate_5',
#  'Activity at 115.2 uM-Replicate_31',
#  'Activity_at_19.5uM_(%)_TEST1',
#  'W460-Activity at 8.078 uM-Replicate_30',
#  'W460-Activity at 79.03 uM-Replicate_25',
#  'Activity at 0.068 uM-Replicate_2',
#  'Activity at 0.191 uM-Replicate_15',
#  'Activity at 31.63 uM-Replicate_36',
#  'W665-Activity at 0.051 uM-Replicate_28',
#  'Activity at 11.82 uM-Replicate_5',
#  'Activity at 0.057 uM-Replicate_46',
#  'Activity at 0.23uM',
#  'Activity at 0.00300 uM-Replicate_1',
#  'Activity at 0.00616 uM-Replicate_13',
#  'W460-Activity at 0.00497 uM-Replicate_23',
#  'Activity at 6.950 uM-Replicate_33',
#  'Ratio-Activity at 0.00101 uM-Replicate_1',
#  'Activity at 0.00497 uM-Replicate_45',
#  'Activity at 0.059 uM-Replicate_6',
#  '% Activity at 40 uM_first_point',
#  'W665-Activity at 1.067 uM-Replicate_40',
#  'Ratio-Activity at 0.151 uM-Replicate_5',
#  'Ratio-Activity at 0.00107 uM-Replicate_3',
#  'Ratio-Activity at 6.976 uM-Replicate_20',
#  'W530-Activity at 0.0009967489 uM-Replicate_35',
#  'W460-Activity at 15.07 uM-Replicate_11',
#  'Ratio-Activity at 0.057 uM-Replicate_10',
#  'W460-Activity at 0.280 uM-Replicate_1',
#  'Activity at 0.0006197192 uM-Replicate_20',
#  'Ratio-Activity at 1.360 uM-Replicate_13',
#  'W460-Activity at 15.76 uM-Replicate_39',
#  'Ratio-Activity at 78.83 uM-Replicate_1',
#  'Ratio-Activity at 1.674 uM-Replicate_8',
#  'W460-Activity at 0.624 uM-Replicate_44',
#  'W615-Activity at 1.067 uM-Replicate_24',
#  'Ratio-Activity at 0.751 uM-Replicate_33',
#  'Activity at 15.83 uM',
#  'W460-Activity at 1.076 uM-Replicate_3',
#  'Ratio-Activity at 0.025 uM-Replicate_1',
#  'Activity at 0.887 uM-Replicate_34',
#  '% Activity at 0.368 uM_first_point',
#  'W615-Activity at 1849.0 uM-Replicate_1',
#  'Activity at 0.0006722596 uM-Replicate_9',
#  'W460-Activity at 2.716 uM-Replicate_8',
#  'Activity at 3.831 uM-Replicate_5',
#  'W460-Activity at 10805.3 uM',
#  'Ratio-Activity at 0.751 uM-Replicate_34',
#  'W530-Activity at 0.00507 uM-Replicate_48',
#  'Activity_at_28.5uM_(%)_TEST1',
#  'UDG-Activity at 0.092 uM',
#  'W460-Activity at 0.0005478319 uM-Replicate_33',
#  'W530-Activity at 62.39 uM-Replicate_29',
#  'Activity at 30.72 uM-Replicate_1',
#  'W530-Activity at 0.00598 uM-Replicate_13',
#  'W530-Activity at 0.00222 uM-Replicate_4',
#  'W530-Activity at 0.00107 uM-Replicate_4',
#  'Activity at 0.085 uM-Replicate_48',
#  'W530-Activity at 6.973 uM-Replicate_14',
#  'Ratio-Activity at 2.854 uM',
#  'W460-Activity at 0.127 uM-Replicate_27',
#  'W615-Activity at 0.00170 uM-Replicate_31',
#  'Activity at 0.0000735600 uM-Replicate_1',
#  'W530-Activity at 0.00227 uM-Replicate_25',
#  'Activity at 11.82 uM-Replicate_4',
#  'Ratio-Activity at 1.415 uM-Replicate_18',
#  'Activity_at_0.08uM_(%)',
#  'W530-Activity at 15.10 uM-Replicate_42',
#  'Ratio-Activity at 0.00531 uM-Replicate_12',
#  'W460-Activity at 0.00432 uM-Replicate_29',
#  'Ratio-Activity at 0.153 uM-Replicate_41',
#  'Activity at 0.068 uM-Replicate_20',
#  'Ratio-Activity at 0.151 uM-Replicate_15',
#  'Activity at 0.040 uM',
#  'Activity_at_0.16uM_(%)_TEST2',
#  'W535-Activity at 8.077 uM-Replicate_20',
#  'W535-Activity at 3.629 uM-Replicate_41',
#  'Activity at 0.00223 uM-Replicate_23',
#  'W530-Activity at 3.630 uM-Replicate_27',
#  'Activity at 8.077 uM-Replicate_38',
#  'Ratio-Activity at 3.725 uM-Replicate_13',
#  'W460-Activity at 35.30 uM-Replicate_7',
#  'W460-Activity at 0.0005556937 uM-Replicate_34',
#  'W460-Activity at 14.95 uM-Replicate_34',
#  'W530-Activity at 2.701 uM-Replicate_19',
#  'Ratio-Activity at 1.674 uM-Replicate_3',
#  'W530-Activity at 0.0002337114 uM-Replicate_3',
#  'W530-Activity at 14.96 uM-Replicate_13',
#  'W460-Activity at 0.00268 uM-Replicate_47',
#  'W590-Activity at 0.00268 uM-Replicate_17',
#  'Activity at 0.0007728882 uM-Replicate_2',
#  'W620-Activity at 154.2 uM-Replicate_42',
#  'W460-Activity at 14.96 uM-Replicate_14',
#  'Ratio-Activity at 1.415 uM-Replicate_40',
#  'W590-Activity at 17.94 uM-Replicate_10',
#  'W530-Activity at 0.00497 uM-Replicate_24',
#  'W460-Activity at 76.84 uM-Replicate_10',
#  'Ratio-Activity at 0.014 uM-Replicate_22',
#  'Activity at 57.62 uM-Replicate_11',
#  'W530-Activity at 0.00531 uM-Replicate_37',
#  'W530-Activity at 6.948 uM-Replicate_23',
#  'Ratio-Activity at 0.0005064679 uM-Replicate_44',
#  'Ratio-Activity at 0.255 uM-Replicate_17',
#  'Ratio-Activity at 0.0001080938 uM-Replicate_2',
#  'Ratio-Activity at 70.06 uM-Replicate_45',
#  'W530-Activity at 0.291 uM-Replicate_42',
#  'W590-Activity at 0.0006614272 uM-Replicate_17',
#  'Ratio-Activity at 0.127 uM-Replicate_19',
#  'W460-Activity at 3.630 uM-Replicate_35',
#  'Activity_at_0.5uM',
#  'Activity at 0.085 uM-Replicate_20',
#  'Activity at 0.0006722596 uM-Replicate_15',
#  'Activity at 0.0005478902 uM-Replicate_1',
#  'Ratio-Activity at 35.48 uM-Replicate_33',
#  'Ratio-Activity at 70.87 uM-Replicate_47',
#  'Activity at 0.017 uM-Replicate_48',
#  'Activity at 154.2 uM-Replicate_30',
#  'W665-Activity at 1.067 uM-Replicate_1',
#  'Activity at 0.00120 uM-Replicate_13',
#  'W460-Activity at 0.00510 uM-Replicate_15',
#  'W460-Activity at 5.947 uM-Replicate_2',
#  'W460-Activity at 0.00107 uM-Replicate_25',
#  'Ratio-Activity at 27.01 uM-Replicate_41',
#  'Ratio-Activity at 95.14 uM-Replicate_7',
#  'Ratio-Activity at 0.114 uM-Replicate_30',
#  'W530-Activity at 13.22 uM-Replicate_33',
#  'Activity at 0.206 uM',
#  'Ratio-Activity at 29.14 uM-Replicate_16',
#  'W530-Activity at 0.00507 uM-Replicate_50',
#  'Activity at 3.746 uM-Replicate_41',
#  'W590-Activity at 0.00598 uM-Replicate_35',
#  'Ratio-Activity at 0.00531 uM-Replicate_13',
#  'W530-Activity at 0.878 uM-Replicate_50',
#  'W530-Activity at 0.030 uM-Replicate_22',
#  'W460-Activity at 1.391 uM-Replicate_30',
#  'Ratio-Activity at 0.0001141219 uM-Replicate_1',
#  'W460-Activity at 0.0001076943 uM-Replicate_1',
#  'W535-Activity at 8.077 uM-Replicate_31',
#  'W530-Activity at 0.125 uM-Replicate_31',
#  'Activity at 69.43 uM-Replicate_8',
#  'W460-Activity at 3.112 uM-Replicate_9',
#  'W460-Activity at 0.0005106135 uM-Replicate_23',
#  'Activity at 32.48 uM-Replicate_4',
#  'Activity at 1.000uM',
#  'W530-Activity at 0.00432 uM-Replicate_32',
#  'W530-Activity at 0.00598 uM-Replicate_46',
#  'W530-Activity at 62.57 uM-Replicate_51',
#  'Activity at 32.90 uM',
#  'Activity at 0.0002523297 uM-Replicate_3',
#  'Activity at 0.055 uM-Replicate_43',
#  'Activity at 0.022 uM-Replicate_20',
#  'W530-Activity at 0.013 uM-Replicate_14',
#  'Ratio-Activity at 15.76 uM-Replicate_12',
#  'W460-Activity at 25.00 uM-Replicate_18',
#  'W460-Activity at 0.0005106135 uM-Replicate_5',
#  'W530-Activity at 14.96 uM-Replicate_10',
#  'Activity at 0.0001216490 uM-Replicate_1',
#  'W590-Activity at 0.066 uM-Replicate_35',
#  'W665-Activity at 0.00284 uM-Replicate_42',
#  'Activity at 0.057 uM-Replicate_7',
#  'W665-Activity at 0.00170 uM-Replicate_24',
#  'Activity at 0.0005152588 uM-Replicate_5',
#  'W530-Activity at 0.634 uM-Replicate_2',
#  'Activity at 0.00223 uM-Replicate_26',
#  'Ratio-Activity at 0.00230 uM-Replicate_22',
#  'W460-Activity at 0.00223 uM-Replicate_23',
#  'W530-Activity at 0.030 uM-Replicate_35',
#  'Ratio-Activity at 32.62 uM-Replicate_34',
#  'W530-Activity at 0.148 uM-Replicate_35',
#  'Activity at 3.154 uM-Replicate_15',
#  'Activity at 3.491 uM-Replicate_1',
#  'W460-Activity at 0.0004949824 uM-Replicate_13',
#  'Ratio-Activity at 14.00 uM-Replicate_3',
#  'W460-Activity at 7.009 uM-Replicate_5',
#  'Ratio-Activity at 0.00226 uM-Replicate_24',
#  'W665-Activity at 0.00284 uM-Replicate_6',
#  'Ratio-Activity at 0.281 uM-Replicate_17',
#  'Ratio-Activity at 15430.0 uM-Replicate_3',
#  'W615-Activity at 0.0006197232 uM-Replicate_21',
#  'W460-Activity at 1.434 uM-Replicate_38',
#  'Activity at 0.0006197192 uM-Replicate_25',
#  'W460-Activity at 58.48 uM-Replicate_45',
#  'W615-Activity at 92.41 uM-Replicate_9',
#  'Activity at 0.00609 uM-Replicate_13',
#  '% Activity at 0.625 uM_first_point',
#  'W460-Activity at 0.280 uM-Replicate_44',
#  'W460-Activity at 7.009 uM-Replicate_48',
#  'Ratio-Activity at 1.422 uM-Replicate_4',
#  'Ratio-Activity at 3.267 uM-Replicate_34',
#  'W460-Activity at 1.391 uM-Replicate_5',
#  'Activity at 0.114 uM-Replicate_13',
#  'Activity at 0.770 uM-Replicate_5',
#  'Activity at 0.671 uM-Replicate_15',
#  'W460-Activity at 0.642 uM-Replicate_30',
#  'W460-Activity at 0.624 uM-Replicate_16',
#  'W665-Activity at 0.022 uM-Replicate_45',
#  'W530-Activity at 872.4 uM-Replicate_3',
#  'Activity at 0.00141 uM-Replicate_34',
#  'Activity at 3.629 uM-Replicate_24',
#  'Activity at 0.127 uM-Replicate_6',
#  'Activity at 0.756 uM-Replicate_4',
#  'W460-Activity at 0.058 uM-Replicate_34',
#  'W460-Activity at 0.126 uM-Replicate_42',
#  'W615-Activity at 18.95 uM-Replicate_45',
#  'W530-Activity at 27.01 uM-Replicate_4',
#  'W460-Activity at 0.00268 uM-Replicate_23',
#  'Ratio-Activity at 42.46 uM-Replicate_41',
#  'Activity_at_0.9uM_(%)_TEST5',
#  'Ratio-Activity at 0.00223 uM-Replicate_20',
#  'Ratio-Activity at 8.300 uM-Replicate_46',
#  'Ratio-Activity at 0.0004939798 uM-Replicate_6',
#  'W460-Activity at 29.14 uM-Replicate_8',
#  'Activity at 8.390 uM-Replicate_8',
#  'Activity at 1.073 uM-Replicate_2',
#  ...]

# %% [markdown]
# Looks like most are in uM, but lot all..

# %%
[col for col in columns_matching[0].values.tolist() if 'uM' not in col]
# Out:
# ['Activity at 1.463 nM',
#  'Activity at 40.90 nM',
#  'Activity_at_0.05mM',
#  'Activity_at_0.042mM',
#  'Activity_at_15nM',
#  'Activity at 0.731 nM',
#  'Activity at 36.57 nM',
#  'Activity at 457.2 nM',
#  'Activity at 3.658 nM',
#  'Activity at 91.45 nM',
#  'Activity at 204.5 nM',
#  'Activity_at_0.038mM',
#  'Activity_at_0.035mM',
#  'Activity_at_18nM',
#  'Activity at 0.732 nM',
#  'Activity at 18.29 nM',
#  'Activity at 182.9 nM',
#  'Activity at 7.314 nM',
#  'Activity_at_13.5nM',
#  'Activity at 1.636 nM',
#  'Activity_at_0.046mM',
#  'Activity at 8.181 nM']

# %%
import warnings

def extract_units(column_string: str) -> float:
    """ given a columns_string pull outthe units
    so far looks like units can be nM, uM or mM 

    """
    units = re.findall('[unm]M', column_string)

    if not units:
        warnings.warn(f"Column: {column_string} could not find units!")
        units = [None]
    if len(units) > 1:
        warnings.warn(f"Column: {column_string} has more than one set of units!")
    return units[0] 

def extract_concentrations(column_string: str) -> float:
    """ given a columns_string pull out concentration 
    https://stackoverflow.com/questions/4289331/how-to-extract-numbers-from-a-string-in-python

    Regexr Website: https://regexr.com, https://regex101.com/

    """
    #digits = re.findall(r'\d+', column_string)
    # find digits surrounded by white space
    #digits = re.findall('\d+\.\d+.uM', column_string)

    # first get units 

    units = extract_units(column_string)
    
    digits = re.findall('\d.*?{}'.format(units), column_string)

    if not digits:
        warnings.warn(f"Column: {column_string} could not find concentration!")
        digits = [None]
    if len(digits) > 1:
        print(digits)
        warnings.warn(f"Column: {column_string} has more than one set of digits!")
    return digits[0]

# %%
columns_matching[0].apply(extract_concentrations)
# Out:
# 0          530-Activity at 60.96 uM
# 1        530-Activity at 24160.9 uM
# 2                   0.0001503265 uM
# 3          460-Activity at 32.86 uM
# 4        530-Activity at 0.00120 uM
#                     ...
# 47526                    0.00273 uM
# 47527      590-Activity at 0.735 uM
# 47528      530-Activity at 62.39 uM
# 47529      530-Activity at 0.610 uM
# 47530                      0.624 uM
# Name: 0, Length: 42570, dtype: object

# %%
columns_matching['Concentation'] = columns_matching[0].apply(extract_concentrations)
# Out:
# /opt/anaconda3/envs/intro-chem/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
columns_matching[columns_matching['Concentation'].isnull()]
# Out:
# Empty DataFrame
# Columns: [0, Concentation]
# Index: []

# %%
columns_matching[0].apply(extract_units).value_counts(dropna=False)
# Out:
# uM    42548
# nM       17
# mM        5
# Name: 0, dtype: int64
